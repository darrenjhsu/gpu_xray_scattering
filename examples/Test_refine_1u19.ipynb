# %%
import numpy as np
from gpu_xray_scattering import XS
from gpu_xray_scattering.Molecule import Molecule
import glob
import MDAnalysis as mda
from MDAnalysis.topology.guessers import guess_types
from scipy.ndimage import binary_erosion, binary_dilation
import numpy.polynomial.polynomial as poly

def readPDB(fname, sel='protein', sel2=None, psf=None):
    if psf is not None:
        U = mda.Universe(psf, fname)
    else:
        U = mda.Universe(fname)
    Usel = U.select_atoms(sel)
    try:
        print(Uele[:3])
        Uele = Usel.elements
    except:
        guessed_elements = guess_types(U.atoms.names)
        U.add_TopologyAttr('elements', guessed_elements)
        
    
    if sel2 is not None:
        Usel2 = U.select_atoms(sel2)
        return Usel.positions, Usel.elements, Usel2.positions, Usel2.elements
    else:
        return Usel.positions, Usel.elements

# %%
pro_coord1, pro_ele1, pro_coord2, pro_ele2 = readPDB('data/1U19/1u19.pdb', sel='protein', sel2='resname RET')
pro_coord, pro_ele = readPDB('data/1U19/1u19.pdb', sel='all')

# %%
# Create grid
def create_grid(coord, pad=1, spacing=0.5, minsize=None):
    # minsize is the side length of the box, can also be rectangular if input is a list/array of length 3
    # otherwise ignored
    minx, miny, minz = coord.min(0)
    maxx, maxy, maxz = coord.max(0)
    cenx, ceny, cenz = coord.min(0) + (coord.max(0) - coord.min(0)) / 2
    if minsize is not None:
        if np.isscalar(minsize):
            minx = np.min([minx, cenx - minsize / 2])
            miny = np.min([miny, ceny - minsize / 2])
            minz = np.min([minz, cenz - minsize / 2])
            maxx = np.max([maxx, cenx + minsize / 2])
            maxy = np.max([maxy, ceny + minsize / 2])
            maxz = np.max([maxz, cenz + minsize / 2])
        elif len(minsize) == 3:
            minx = np.min([minx, cenx - minsize[0] / 2])
            miny = np.min([miny, ceny - minsize[1] / 2])
            minz = np.min([minz, cenz - minsize[2] / 2])
            maxx = np.max([maxx, cenx + minsize[0] / 2])
            maxy = np.max([maxy, ceny + minsize[1] / 2])
            maxz = np.max([maxz, cenz + minsize[2] / 2])
        else:
            print(f"minsize is set as {minsize} but we don't know what to do with it")
    x_ = np.arange(minx - pad, maxx + pad, spacing)
    y_ = np.arange(miny - pad, maxy + pad, spacing)
    z_ = np.arange(minz - pad, maxz + pad, spacing)
    numx = len(x_)
    numy = len(y_)
    numz = len(z_)
    xyz = np.array([(x, y, z) for x in x_ for y in y_ for z in z_])
    xyzd = np.array((numx, numy, numz))
    print(f'Grid will be [{numx}, {numy}, {numz}] ({numx*numy*numz} elements)')
    return xyz, xyzd

# %%
spacing = 0.75
pad = 1
minsize = 20
xyz, xyzd = create_grid(pro_coord2, spacing=spacing, pad=pad, minsize=minsize)
# Out:
# Grid will be [30, 30, 30] (27000 elements)

# %%
def overlap(coord1, coord2, radius=1):
    # returns if points in coord2 overlaps with coord1 within radius
    return (((coord1[:, :, None] - coord2[:, :, None].T)**2).sum(1) < radius**2).sum(0) == 0

# %%
allowed_points = overlap(pro_coord1, xyz, radius=2)

# %%
allowed_points = allowed_points.reshape(xyzd)

# %%
allowed_origins = binary_erosion(allowed_points, iterations=int(2/spacing))

# %%
print(allowed_points.sum(), allowed_origins.sum())
# Out:
# 7795 535

# %%
def get_trial_sphere(xyz, allowed_origin, allowed_volume, dilation=2):
    # Returns a list of length len(allowed_origin) which includes points for trial
#     print(np.argwhere(allowed_origin))
    
    trial_list = []
    trial_idx = []
    for idx, (x, y, z) in enumerate(np.argwhere(allowed_origin)):
        vol = np.zeros_like(allowed_volume)
        if idx > 0 and idx % 1000 == 0:
            print(idx)
        vol[x, y, z] = True
        vol = binary_dilation(vol, iterations=dilation) * allowed_volume
        trial_list.append(xyz[np.argwhere(vol.ravel()).flatten()])
        trial_idx.append(np.argwhere(vol.ravel()).flatten())
#         print()
    print('done')
    return trial_list, trial_idx

# %%
trial_list, trial_idx = \
    get_trial_sphere(xyz, allowed_origins, allowed_points, dilation=int(2.5/spacing))
# Out:
# done

# %%
scatter = XS.Scatter(q=np.linspace(0.03, 1.2, num=160), use_oa=1)

# %%
pro_all = Molecule(coordinates=pro_coord, elements=pro_ele)
pro = Molecule(coordinates=pro_coord1, elements=pro_ele1)

# %%
S_calc_all = scatter.scatter(pro_all, timing=False)
S_calc_all = scatter.scatter(pro_all, timing=True)
S_calc_pro_before = scatter.scatter(pro, timing=False)
S_err = S_calc_all * 0.03
# Out:
# Elapsed time = 9.823 ms

# %%
# Solve for the scaling factor for trial density

def res_func_analytical(Idata, Iprior, Icross, Iguess, sigqdata):
    a = np.sum(2 * Icross * (Idata - Iprior) / sigqdata**2) # zeroth order term
    b = np.sum(-(4 * Icross**2 - 2 * Iguess * (Idata - Iprior)) / sigqdata**2)
    c = np.sum(-6 * Iguess * Icross / sigqdata**2)
    d = np.sum(-2 * Iguess**2 / sigqdata**2)
    eq = poly.Polynomial((a, b, c, d))
    roots = eq.roots()
#     print(f'analytical roots: {roots}')
    chi = np.inf
    root_best = 0
    for root_c in roots[np.isreal(roots)]:
        root = root_c.real
        chi_this = np.sum(((Idata - Iprior - Icross * 2 * root - Iguess * root * root) / sigqdata)**2)/Idata.size
        if chi_this < chi:
            chi = chi_this
            root_best = root
#     print(f'analytical gives {chi} at {root_best}')
    return root_best
# Add to weight
# Flatten negative weight

# %%
def write_pdb_line(f,*j):
    j = list(j)
    j[0] = j[0].ljust(6)#atom#6s
    j[1] = j[1].rjust(5)#aomnum#5d
    j[2] = j[2].center(4)#atomname$#4s
    j[3] = j[3].ljust(3)#resname#1s
    j[4] = j[4].rjust(1) #Astring
    j[5] = j[5].rjust(4) #resnum
    j[6] = str('%8.3f' % (float(j[6]))).rjust(8) #x
    j[7] = str('%8.3f' % (float(j[7]))).rjust(8)#y
    j[8] = str('%8.3f' % (float(j[8]))).rjust(8) #z\
    j[9] =str('%6.2f'%(float(j[9]))).rjust(6)#occ
    j[10]=str('%6.2f'%(float(j[10]))).ljust(6)#temp
    j[11]=j[11].rjust(12)#elname
    f.write("%s%s %s %s %s%s    %s%s%s%s%s%s\n"% (j[0],j[1],j[2],j[3],j[4],j[5],j[6],j[7],j[8],j[9],j[10],j[11]))
            
def write_out(xyz, weight, fname, grid=None, op=None, mode='w', save_space=True):
    with open(fname, mode) as f:
        for i_ in range(len(xyz)):
            if weight[i_] > 0 or not save_space:
                i = i_ + 1
                write_pdb_line(f,'ATOM', str(i), 'X', 'X', 'A', '1', *xyz[i_], weight[i_]*100, 1.0, 'X')
        f.write('END\n')

    if grid is not None:
        if op is not None:
            allowed = op.flatten()
        else:
            allowed = np.ones_like(weight)
        with open(grid, mode) as f:
            for i_ in range(len(xyz)):
#                 if weight[i_] > 0:
                    i = i_ + 1
                    write_pdb_line(f,'ATOM', str(i), 'X', 'X', 'A', '1', *xyz[i_], allowed[i_], 1.0, 'X')
            f.write('END\n')

# %%
import time
from scipy import ndimage
def refine(xyz, trial_list, op, S_calc_all, S_err, scatter,
           steps=10000,
           timing_step=500,
           flatten_step=100,
           connectivity_step=1000,
           weight_max=0.05,
           struct_connectivity_A=4,
           grid_spacing=0.75,
           start_refine=5000,
           do_trial=True,
           write_traj=None,
           write_fname=None,
           input_weight=None):
    
    n_origins = len(trial_list)
    if input_weight is None:
        weight = np.random.random(len(xyz))
        weight[~op.flatten()] = 0
        S_calc_pro, S_calc_trial, S_calc_cross = \
                scatter.cross_scatter(pro, prior=np.empty((0, 3)), weight_p=np.empty(0), 
                                      trial=xyz[op.flatten()], weight_t=weight[op.flatten()], timing=True)
        S_calc_pro_before = S_calc_pro.copy() # Initial curve

        chi_zero = (((S_calc_all - S_calc_pro) / S_err)**2).sum() / (len(S_calc_all) - 1)
        chi_before = (((S_calc_all - S_calc_pro - S_calc_trial - 2 * S_calc_cross) / S_err)**2).sum() / (len(S_calc_all) - 1)
        scaling = res_func_analytical(S_calc_all, S_calc_pro, S_calc_cross, S_calc_trial, S_err)
        print(f'Initial scaling: {scaling:.3f}')
        weight[op.flatten()] *= scaling
        weight_trial = weight.copy()
        S_calc_pro, _, _ = \
                scatter.cross_scatter(pro, prior=xyz, weight_p=weight, 
                                      trial=xyz, timing=True)
        chi_after = (((S_calc_all - S_calc_pro) / S_err)**2).sum() / (len(S_calc_all) - 1)
        print(chi_zero, chi_before, chi_after, (weight>0).sum())
    else:
        weight = input_weight
        
    chi_trace = []
    scale_trace = []
    fine_timing_trace = []


    timing_step = timing_step
    flatten_step = flatten_step
    connectivity_step = connectivity_step
    weight_max = weight_max
    struct_connectivity = int(struct_connectivity_A / spacing)
    start_refine = start_refine
    trial = do_trial
    write_traj = write_traj
    if trial:
        weight_trial = weight.copy()

    t0 = time.time()
    t01 = time.time()
    for idx in range(steps+1):

        choice = np.random.choice(np.arange(n_origins))
        if idx > start_refine:
            while (weight[trial_idx[choice]] > 0).sum() < len(trial_idx[choice]) / 2:
                # limit sampling to near existing density
                choice = np.random.choice(np.arange(n_origins))
        S_calc_pro, S_calc_trial, S_calc_cross = \
            scatter.cross_scatter(pro, prior=xyz[weight > 0], weight_p=weight[weight > 0], 
                                  trial=trial_list[choice], timing=False)
        chi_before = (((S_calc_all - S_calc_pro) / S_err)**2).sum() / (len(S_calc_all) - 1)
        scaling = res_func_analytical(S_calc_all, S_calc_pro, S_calc_cross, S_calc_trial, S_err)



        if trial:
            # Risk of increasing chi^2, so recalc 
            weight_trial[trial_idx[choice]] += scaling
            weight_trial[weight_trial<0] = 0
            S_calc_pro, S_calc_trial, S_calc_cross = \
                scatter.cross_scatter(pro, prior=xyz[weight_trial > 0], weight_p=weight_trial[weight_trial > 0], 
                                      trial=trial_list[choice], timing=False)
            chi_after = (((S_calc_all - S_calc_pro) / S_err)**2).sum() / (len(S_calc_all) - 1)

            if chi_after < chi_before:
                weight = weight_trial.copy()
                scale_trace.append(scaling)
            else:
                weight_trial = weight.copy()
                scale_trace.append(np.nan)
            chi = min(chi_after, chi_before)
        else:
            chi = chi_before
            scale_trace.append(scaling)
            weight[trial_idx[choice]] += scaling
            weight[weight<0] = 0

        chi_trace.append(chi)    

        if flatten_step is not None and idx > 0 and idx % flatten_step == 0:
            # flatten
            weight[weight < weight.max() * weight_max] = 0

        if connectivity_step is not None and idx > 0 and idx % connectivity_step == 0:
            # Pick largest feature
            struct = ndimage.generate_binary_structure(3, struct_connectivity)
            labeled_support, num_features = ndimage.label(weight.reshape(op.shape), structure=struct)
            labeled_support = labeled_support.flatten()
            sums = np.zeros((num_features))

            #find the feature with the greatest number of electrons
            for feature in range(num_features+1):
                sums[feature-1] = np.sum(weight[labeled_support==feature])
            big_feature = np.argmax(sums)+1

            #remove features from the support that are not the primary feature
            weight[labeled_support != big_feature] = 0
            print()
            print(f'Stray feature removal: Map has {num_features} blobs, removing {num_features-1} of them')
            print(f'Zeroed {sums.sum() - np.max(sums):.2f} carbon-equivalents, {np.max(sums):.2f} remaining')

        if write_traj is not None and idx > 0 and idx % write_traj == 0:
            if idx == write_traj:
                write_out(xyz, weight, 'traj.pdb', mode='w', save_space=False)
            else:
                write_out(xyz, weight, 'traj.pdb', mode='a', save_space=False)


        if timing_step is not None and idx > 0 and idx % timing_step == 0:
            t1 = time.time()
            if idx == timing_step:
                t2 = t0
            print(f'Timing step {idx}: {(t1 - t0):.2f}s ({(t1-t0)/idx*1000:.2f} ms/step | {idx/(t1-t0):.2f} steps/s | ', end='')
            print(f'this {timing_step} steps: {timing_step/(t1-t2):.2f} steps/s)')
            t2 = time.time()

        print(f'Step {idx:4d}: scaling = {scaling:.4e}, chi^2 = {chi:.4e}', end='\r')
        t00 = time.time()
        fine_timing_trace.append(t00 - t01)
        t01 = time.time()
    final_S_calc, _ , _ = \
            scatter.cross_scatter(pro, prior=xyz[weight_trial > 0], weight_p=weight_trial[weight_trial > 0], 
                                  trial=trial_list[choice], timing=False)
    return weight, chi_trace, scale_trace, fine_timing_trace, final_S_calc

# %%
weight_list = []
chi_list = []
for idx in range(10):
    print(f'\n\n### Run {idx} ###')
    weight, chi_trace, scale_trace, fine_timing_trace, final_S_calc = \
        refine(xyz, trial_list, allowed_points, S_calc_all, S_err, scatter, grid_spacing=spacing,
               steps=10000)#, input_weight=weight.copy())
    weight_list.append(weight)
    chi_list.append(chi_trace[-1])
# Out:
# ### Run 0 ###
# Elapsed time = 137.424 ms
# Initial scaling: 0.009
# Elapsed time = 281.533 ms
# 0.19522457656989434 40604.764787040665 0.10278101092849619 7795
# Timing step 500: 23.23s (46.46 ms/step | 21.52 steps/s | this 500 steps: 21.52 steps/s)
# Step  999: scaling = -2.1947e-02, chi^2 = 1.0087e-02
# Stray feature removal: Map has 7 blobs, removing 6 of them
# Zeroed 3.92 carbon-equivalents, 13.62 remaining
# Timing step 1000: 45.70s (45.70 ms/step | 21.88 steps/s | this 500 steps: 22.25 steps/s)
# Timing step 1500: 67.98s (45.32 ms/step | 22.07 steps/s | this 500 steps: 22.45 steps/s)
# Step 1999: scaling = -1.5988e-02, chi^2 = 8.9830e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 4.33 carbon-equivalents, 13.08 remaining
# Timing step 2000: 90.74s (45.37 ms/step | 22.04 steps/s | this 500 steps: 21.97 steps/s)
# Timing step 2500: 113.51s (45.41 ms/step | 22.02 steps/s | this 500 steps: 21.95 steps/s)
# Step 2999: scaling = -1.0081e-02, chi^2 = 8.5340e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 3.96 carbon-equivalents, 13.45 remaining
# Timing step 3000: 136.34s (45.45 ms/step | 22.00 steps/s | this 500 steps: 21.90 steps/s)
# Timing step 3500: 159.35s (45.53 ms/step | 21.96 steps/s | this 500 steps: 21.74 steps/s)
# Step 3999: scaling = -1.6499e-02, chi^2 = 8.3956e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 4.61 carbon-equivalents, 13.63 remaining
# Timing step 4000: 182.36s (45.59 ms/step | 21.93 steps/s | this 500 steps: 21.73 steps/s)
# Timing step 4500: 205.81s (45.74 ms/step | 21.86 steps/s | this 500 steps: 21.32 steps/s)
# Step 4999: scaling = -2.2269e-04, chi^2 = 7.4371e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 4.71 carbon-equivalents, 12.79 remaining
# Timing step 5000: 228.84s (45.77 ms/step | 21.85 steps/s | this 500 steps: 21.71 steps/s)
# Timing step 5500: 252.02s (45.82 ms/step | 21.82 steps/s | this 500 steps: 21.57 steps/s)
# Step 5999: scaling = 1.6653e-04, chi^2 = 7.1241e-033
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 4.22 carbon-equivalents, 13.13 remaining
# Timing step 6000: 275.53s (45.92 ms/step | 21.78 steps/s | this 500 steps: 21.27 steps/s)
# Timing step 6500: 298.99s (46.00 ms/step | 21.74 steps/s | this 500 steps: 21.31 steps/s)
# Step 6999: scaling = -6.8227e-03, chi^2 = 7.0521e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 4.36 carbon-equivalents, 13.02 remaining
# Timing step 7000: 322.50s (46.07 ms/step | 21.71 steps/s | this 500 steps: 21.27 steps/s)
# Timing step 7500: 346.17s (46.16 ms/step | 21.67 steps/s | this 500 steps: 21.12 steps/s)
# Step 7999: scaling = 7.5002e-05, chi^2 = 6.9574e-033
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 4.22 carbon-equivalents, 12.83 remaining
# Timing step 8000: 369.83s (46.23 ms/step | 21.63 steps/s | this 500 steps: 21.13 steps/s)
# Timing step 8500: 393.57s (46.30 ms/step | 21.60 steps/s | this 500 steps: 21.06 steps/s)
# Step 8999: scaling = 5.0115e-04, chi^2 = 6.8332e-033
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 4.03 carbon-equivalents, 12.75 remaining
# Timing step 9000: 417.37s (46.37 ms/step | 21.56 steps/s | this 500 steps: 21.01 steps/s)
# Timing step 9500: 440.87s (46.41 ms/step | 21.55 steps/s | this 500 steps: 21.28 steps/s)
# Step 9999: scaling = 1.2009e-06, chi^2 = 6.7383e-033
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 3.93 carbon-equivalents, 12.66 remaining
# Timing step 10000: 464.62s (46.46 ms/step | 21.52 steps/s | this 500 steps: 21.05 steps/s)
# Step 10000: scaling = 6.6490e-04, chi^2 = 6.7369e-03
#
# ### Run 1 ###
# Elapsed time = 22.814 ms
# Initial scaling: 0.009
# Elapsed time = 100.643 ms
# 0.19522457656989434 39381.14606226346 0.10393956302426309 7795
# Timing step 500: 24.84s (49.68 ms/step | 20.13 steps/s | this 500 steps: 20.13 steps/s)
# Step  999: scaling = -2.8929e-03, chi^2 = 1.0628e-02
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 4.36 carbon-equivalents, 13.31 remaining
# Timing step 1000: 49.02s (49.02 ms/step | 20.40 steps/s | this 500 steps: 20.68 steps/s)
# Timing step 1500: 72.33s (48.22 ms/step | 20.74 steps/s | this 500 steps: 21.45 steps/s)
# Step 1999: scaling = -7.7116e-03, chi^2 = 8.6623e-03
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 3.91 carbon-equivalents, 13.65 remaining
# Timing step 2000: 95.82s (47.91 ms/step | 20.87 steps/s | this 500 steps: 21.28 steps/s)
# Timing step 2500: 119.06s (47.63 ms/step | 21.00 steps/s | this 500 steps: 21.51 steps/s)
# Step 2999: scaling = -3.4894e-03, chi^2 = 7.9441e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 4.41 carbon-equivalents, 13.52 remaining
# Timing step 3000: 142.36s (47.45 ms/step | 21.07 steps/s | this 500 steps: 21.46 steps/s)
# Timing step 3500: 166.52s (47.58 ms/step | 21.02 steps/s | this 500 steps: 20.70 steps/s)
# Step 3999: scaling = -7.7272e-04, chi^2 = 7.9414e-03
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 8.52 carbon-equivalents, 9.16 remaining
# Timing step 4000: 193.70s (48.42 ms/step | 20.65 steps/s | this 500 steps: 18.39 steps/s)
# Timing step 4500: 219.97s (48.88 ms/step | 20.46 steps/s | this 500 steps: 19.03 steps/s)
# Step 4999: scaling = -8.1061e-03, chi^2 = 8.1777e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.05 carbon-equivalents, 13.12 remaining
# Timing step 5000: 245.58s (49.12 ms/step | 20.36 steps/s | this 500 steps: 19.53 steps/s)
# Timing step 5500: 271.18s (49.31 ms/step | 20.28 steps/s | this 500 steps: 19.53 steps/s)
# Step 5999: scaling = 2.7183e-04, chi^2 = 7.5708e-033
# Stray feature removal: Map has 10 blobs, removing 9 of them
# Zeroed 4.69 carbon-equivalents, 13.44 remaining
# Timing step 6000: 295.34s (49.22 ms/step | 20.32 steps/s | this 500 steps: 20.70 steps/s)
# Timing step 6500: 321.12s (49.40 ms/step | 20.24 steps/s | this 500 steps: 19.39 steps/s)
# Step 6999: scaling = -5.5511e-04, chi^2 = 7.3425e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.57 carbon-equivalents, 13.12 remaining
# Timing step 7000: 346.85s (49.55 ms/step | 20.18 steps/s | this 500 steps: 19.43 steps/s)
# Timing step 7500: 374.42s (49.92 ms/step | 20.03 steps/s | this 500 steps: 18.14 steps/s)
# Step 7999: scaling = 3.7358e-04, chi^2 = 7.2895e-033
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.68 carbon-equivalents, 13.53 remaining
# Timing step 8000: 401.72s (50.22 ms/step | 19.91 steps/s | this 500 steps: 18.31 steps/s)
# Timing step 8500: 428.46s (50.41 ms/step | 19.84 steps/s | this 500 steps: 18.70 steps/s)
# Step 8999: scaling = 4.6954e-04, chi^2 = 7.2540e-033
# Stray feature removal: Map has 11 blobs, removing 10 of them
# Zeroed 4.86 carbon-equivalents, 13.42 remaining
# Timing step 9000: 453.51s (50.39 ms/step | 19.85 steps/s | this 500 steps: 19.96 steps/s)
# Timing step 9500: 477.47s (50.26 ms/step | 19.90 steps/s | this 500 steps: 20.87 steps/s)
# Step 9999: scaling = -3.4896e-03, chi^2 = 7.2324e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.72 carbon-equivalents, 13.35 remaining
# Timing step 10000: 501.77s (50.18 ms/step | 19.93 steps/s | this 500 steps: 20.58 steps/s)
# Step 10000: scaling = -1.2869e-03, chi^2 = 7.2322e-03
#
# ### Run 2 ###
# Elapsed time = 24.155 ms
# Initial scaling: 0.009
# Elapsed time = 104.822 ms
# 0.19522457656989434 39236.22473118646 0.10364399956682471 7795
# Timing step 500: 26.02s (52.04 ms/step | 19.22 steps/s | this 500 steps: 19.22 steps/s)
# Step  999: scaling = -4.3106e-02, chi^2 = 1.3505e-02
# Stray feature removal: Map has 7 blobs, removing 6 of them
# Zeroed 5.64 carbon-equivalents, 14.87 remaining
# Timing step 1000: 50.04s (50.04 ms/step | 19.98 steps/s | this 500 steps: 20.81 steps/s)
# Timing step 1500: 74.30s (49.54 ms/step | 20.19 steps/s | this 500 steps: 20.61 steps/s)
# Step 1999: scaling = -2.4427e-02, chi^2 = 9.8775e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 6.10 carbon-equivalents, 14.30 remaining
# Timing step 2000: 98.97s (49.49 ms/step | 20.21 steps/s | this 500 steps: 20.27 steps/s)
# Timing step 2500: 123.75s (49.50 ms/step | 20.20 steps/s | this 500 steps: 20.18 steps/s)
# Step 2999: scaling = -8.5547e-03, chi^2 = 8.4144e-03
# Stray feature removal: Map has 7 blobs, removing 6 of them
# Zeroed 5.59 carbon-equivalents, 13.91 remaining
# Timing step 3000: 148.38s (49.46 ms/step | 20.22 steps/s | this 500 steps: 20.30 steps/s)
# Timing step 3500: 172.52s (49.29 ms/step | 20.29 steps/s | this 500 steps: 20.71 steps/s)
# Step 3999: scaling = -2.1061e-02, chi^2 = 8.4644e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 5.36 carbon-equivalents, 14.16 remaining
# Timing step 4000: 197.20s (49.30 ms/step | 20.28 steps/s | this 500 steps: 20.26 steps/s)
# Timing step 4500: 221.36s (49.19 ms/step | 20.33 steps/s | this 500 steps: 20.70 steps/s)
# Step 4999: scaling = -2.1317e-03, chi^2 = 7.7334e-03
# Stray feature removal: Map has 10 blobs, removing 9 of them
# Zeroed 6.06 carbon-equivalents, 12.97 remaining
# Timing step 5000: 245.74s (49.15 ms/step | 20.35 steps/s | this 500 steps: 20.50 steps/s)
# Timing step 5500: 270.06s (49.10 ms/step | 20.37 steps/s | this 500 steps: 20.56 steps/s)
# Step 5999: scaling = -2.3900e-03, chi^2 = 7.3926e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 5.67 carbon-equivalents, 13.60 remaining
# Timing step 6000: 294.19s (49.03 ms/step | 20.40 steps/s | this 500 steps: 20.72 steps/s)
# Timing step 6500: 318.42s (48.99 ms/step | 20.41 steps/s | this 500 steps: 20.63 steps/s)
# Step 6999: scaling = -2.5303e-03, chi^2 = 7.3738e-03
# Stray feature removal: Map has 10 blobs, removing 9 of them
# Zeroed 4.72 carbon-equivalents, 13.81 remaining
# Timing step 7000: 342.32s (48.90 ms/step | 20.45 steps/s | this 500 steps: 20.92 steps/s)
# Timing step 7500: 366.50s (48.87 ms/step | 20.46 steps/s | this 500 steps: 20.68 steps/s)
# Step 7999: scaling = -1.8546e-03, chi^2 = 7.2038e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.82 carbon-equivalents, 13.68 remaining
# Timing step 8000: 390.67s (48.83 ms/step | 20.48 steps/s | this 500 steps: 20.69 steps/s)
# Timing step 8500: 414.44s (48.76 ms/step | 20.51 steps/s | this 500 steps: 21.03 steps/s)
# Step 8999: scaling = -6.6333e-05, chi^2 = 7.1683e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.64 carbon-equivalents, 13.61 remaining
# Timing step 9000: 438.32s (48.70 ms/step | 20.53 steps/s | this 500 steps: 20.94 steps/s)
# Timing step 9500: 462.35s (48.67 ms/step | 20.55 steps/s | this 500 steps: 20.80 steps/s)
# Step 9999: scaling = -7.1539e-04, chi^2 = 7.1491e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 4.43 carbon-equivalents, 13.55 remaining
# Timing step 10000: 486.19s (48.62 ms/step | 20.57 steps/s | this 500 steps: 20.98 steps/s)
# Step 10000: scaling = 2.0050e-04, chi^2 = 7.1491e-03
#
# ### Run 3 ###
# Elapsed time = 25.243 ms
# Initial scaling: 0.009
# Elapsed time = 116.755 ms
# 0.19522457656989434 40426.58753462074 0.10240554265938168 7795
# Timing step 500: 19.03s (38.05 ms/step | 26.28 steps/s | this 500 steps: 26.28 steps/s)
# Step  999: scaling = 3.4532e-04, chi^2 = 1.7114e-033
# Stray feature removal: Map has 249 blobs, removing 248 of them
# Zeroed 8.40 carbon-equivalents, 19.40 remaining
# Timing step 1000: 36.62s (36.62 ms/step | 27.31 steps/s | this 500 steps: 28.42 steps/s)
# Timing step 1500: 53.19s (35.46 ms/step | 28.20 steps/s | this 500 steps: 30.17 steps/s)
# Step 1999: scaling = 3.2771e-04, chi^2 = 1.0921e-033
# Stray feature removal: Map has 251 blobs, removing 250 of them
# Zeroed 7.24 carbon-equivalents, 18.88 remaining
# Timing step 2000: 70.56s (35.28 ms/step | 28.34 steps/s | this 500 steps: 28.79 steps/s)
# Timing step 2500: 87.37s (34.95 ms/step | 28.61 steps/s | this 500 steps: 29.74 steps/s)
# Step 2999: scaling = -1.4851e-03, chi^2 = 8.6025e-04
# Stray feature removal: Map has 250 blobs, removing 249 of them
# Zeroed 6.79 carbon-equivalents, 18.67 remaining
# Timing step 3000: 104.56s (34.85 ms/step | 28.69 steps/s | this 500 steps: 29.09 steps/s)
# Timing step 3500: 121.20s (34.63 ms/step | 28.88 steps/s | this 500 steps: 30.05 steps/s)
# Step 3999: scaling = 6.6703e-04, chi^2 = 7.3525e-044
# Stray feature removal: Map has 252 blobs, removing 251 of them
# Zeroed 6.40 carbon-equivalents, 18.63 remaining
# Timing step 4000: 138.54s (34.64 ms/step | 28.87 steps/s | this 500 steps: 28.83 steps/s)
# Timing step 4500: 155.37s (34.53 ms/step | 28.96 steps/s | this 500 steps: 29.71 steps/s)
# Step 4999: scaling = -1.2149e-03, chi^2 = 6.5644e-04
# Stray feature removal: Map has 255 blobs, removing 254 of them
# Zeroed 6.06 carbon-equivalents, 18.48 remaining
# Timing step 5000: 173.38s (34.68 ms/step | 28.84 steps/s | this 500 steps: 27.77 steps/s)
# Timing step 5500: 190.91s (34.71 ms/step | 28.81 steps/s | this 500 steps: 28.51 steps/s)
# Step 5999: scaling = 2.7583e-04, chi^2 = 6.3545e-044
# Stray feature removal: Map has 255 blobs, removing 254 of them
# Zeroed 6.05 carbon-equivalents, 18.38 remaining
# Timing step 6000: 208.19s (34.70 ms/step | 28.82 steps/s | this 500 steps: 28.93 steps/s)
# Timing step 6500: 225.81s (34.74 ms/step | 28.79 steps/s | this 500 steps: 28.38 steps/s)
# Step 6999: scaling = -4.5163e-04, chi^2 = 5.7630e-04
# Stray feature removal: Map has 255 blobs, removing 254 of them
# Zeroed 7.97 carbon-equivalents, 15.90 remaining
# Timing step 7000: 243.07s (34.72 ms/step | 28.80 steps/s | this 500 steps: 28.98 steps/s)
# Timing step 7500: 260.66s (34.76 ms/step | 28.77 steps/s | this 500 steps: 28.41 steps/s)
# Step 7999: scaling = 5.8717e-06, chi^2 = 6.3268e-044
# Stray feature removal: Map has 250 blobs, removing 249 of them
# Zeroed 5.81 carbon-equivalents, 18.08 remaining
# Timing step 8000: 277.83s (34.73 ms/step | 28.79 steps/s | this 500 steps: 29.13 steps/s)
# Timing step 8500: 295.25s (34.74 ms/step | 28.79 steps/s | this 500 steps: 28.70 steps/s)
# Step 8999: scaling = -1.7294e-04, chi^2 = 6.2434e-04
# Stray feature removal: Map has 47 blobs, removing 46 of them
# Zeroed 2.44 carbon-equivalents, 17.50 remaining
# Timing step 9000: 312.43s (34.71 ms/step | 28.81 steps/s | this 500 steps: 29.10 steps/s)
# Timing step 9500: 330.20s (34.76 ms/step | 28.77 steps/s | this 500 steps: 28.13 steps/s)
# Step 9999: scaling = 4.2866e-05, chi^2 = 7.0663e-044
# Stray feature removal: Map has 7 blobs, removing 6 of them
# Zeroed 1.57 carbon-equivalents, 17.29 remaining
# Timing step 10000: 347.59s (34.76 ms/step | 28.77 steps/s | this 500 steps: 28.75 steps/s)
# Step 10000: scaling = 5.3583e-04, chi^2 = 7.0574e-04
#
# ### Run 4 ###
# Elapsed time = 24.258 ms
# Initial scaling: 0.009
# Elapsed time = 103.132 ms
# 0.19522457656989434 40262.548578204754 0.10185471696121798 7795
# Timing step 500: 25.91s (51.83 ms/step | 19.29 steps/s | this 500 steps: 19.29 steps/s)
# Step  999: scaling = -1.9357e-02, chi^2 = 1.1147e-02
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 4.74 carbon-equivalents, 13.85 remaining
# Timing step 1000: 50.35s (50.35 ms/step | 19.86 steps/s | this 500 steps: 20.46 steps/s)
# Timing step 1500: 72.94s (48.63 ms/step | 20.56 steps/s | this 500 steps: 22.13 steps/s)
# Step 1999: scaling = -3.1538e-03, chi^2 = 1.4736e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 7.50 carbon-equivalents, 16.98 remaining
# Timing step 2000: 88.15s (44.08 ms/step | 22.69 steps/s | this 500 steps: 32.87 steps/s)
# Timing step 2500: 104.34s (41.74 ms/step | 23.96 steps/s | this 500 steps: 30.89 steps/s)
# Step 2999: scaling = -7.4753e-04, chi^2 = 1.1279e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 6.24 carbon-equivalents, 16.75 remaining
# Timing step 3000: 120.15s (40.05 ms/step | 24.97 steps/s | this 500 steps: 31.62 steps/s)
# Timing step 3500: 136.81s (39.09 ms/step | 25.58 steps/s | this 500 steps: 30.01 steps/s)
# Step 3999: scaling = 5.6889e-04, chi^2 = 8.3774e-044
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.93 carbon-equivalents, 16.30 remaining
# Timing step 4000: 153.54s (38.39 ms/step | 26.05 steps/s | this 500 steps: 29.89 steps/s)
# Timing step 4500: 170.18s (37.82 ms/step | 26.44 steps/s | this 500 steps: 30.05 steps/s)
# Step 4999: scaling = 4.8908e-06, chi^2 = 4.3521e-044
# Stray feature removal: Map has 13 blobs, removing 12 of them
# Zeroed 4.18 carbon-equivalents, 17.24 remaining
# Timing step 5000: 187.01s (37.40 ms/step | 26.74 steps/s | this 500 steps: 29.71 steps/s)
# Timing step 5500: 203.68s (37.03 ms/step | 27.00 steps/s | this 500 steps: 30.00 steps/s)
# Step 5999: scaling = 1.2270e-04, chi^2 = 4.0860e-044
# Stray feature removal: Map has 11 blobs, removing 10 of them
# Zeroed 3.60 carbon-equivalents, 17.61 remaining
# Timing step 6000: 220.66s (36.78 ms/step | 27.19 steps/s | this 500 steps: 29.45 steps/s)
# Timing step 6500: 237.66s (36.56 ms/step | 27.35 steps/s | this 500 steps: 29.41 steps/s)
# Step 6999: scaling = -2.3240e-04, chi^2 = 3.2623e-04
# Stray feature removal: Map has 14 blobs, removing 13 of them
# Zeroed 2.96 carbon-equivalents, 17.23 remaining
# Timing step 7000: 254.09s (36.30 ms/step | 27.55 steps/s | this 500 steps: 30.43 steps/s)
# Timing step 7500: 270.23s (36.03 ms/step | 27.75 steps/s | this 500 steps: 30.97 steps/s)
# Step 7999: scaling = -2.2685e-04, chi^2 = 3.4192e-04
# Stray feature removal: Map has 13 blobs, removing 12 of them
# Zeroed 3.73 carbon-equivalents, 17.06 remaining
# Timing step 8000: 286.38s (35.80 ms/step | 27.93 steps/s | this 500 steps: 30.96 steps/s)
# Timing step 8500: 302.14s (35.55 ms/step | 28.13 steps/s | this 500 steps: 31.73 steps/s)
# Step 8999: scaling = -3.7941e-04, chi^2 = 3.0794e-04
# Stray feature removal: Map has 10 blobs, removing 9 of them
# Zeroed 3.58 carbon-equivalents, 17.68 remaining
# Timing step 9000: 319.02s (35.45 ms/step | 28.21 steps/s | this 500 steps: 29.61 steps/s)
# Timing step 9500: 335.41s (35.31 ms/step | 28.32 steps/s | this 500 steps: 30.51 steps/s)
# Step 9999: scaling = -4.1991e-04, chi^2 = 3.0730e-04
# Stray feature removal: Map has 11 blobs, removing 10 of them
# Zeroed 3.32 carbon-equivalents, 17.63 remaining
# Timing step 10000: 352.07s (35.21 ms/step | 28.40 steps/s | this 500 steps: 30.03 steps/s)
# Step 10000: scaling = 1.8133e-04, chi^2 = 3.0722e-04
#
# ### Run 5 ###
# Elapsed time = 23.591 ms
# Initial scaling: 0.009
# Elapsed time = 103.500 ms
# 0.19522457656989434 39750.72814126047 0.1033684896357197 7795
# Timing step 500: 25.57s (51.14 ms/step | 19.55 steps/s | this 500 steps: 19.55 steps/s)
# Step  999: scaling = -3.5340e-03, chi^2 = 9.5802e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 11.34 carbon-equivalents, 8.70 remaining
# Timing step 1000: 50.53s (50.53 ms/step | 19.79 steps/s | this 500 steps: 20.03 steps/s)
# Timing step 1500: 74.62s (49.74 ms/step | 20.10 steps/s | this 500 steps: 20.76 steps/s)
# Step 1999: scaling = -5.4841e-04, chi^2 = 9.6822e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 7.14 carbon-equivalents, 13.87 remaining
# Timing step 2000: 98.97s (49.49 ms/step | 20.21 steps/s | this 500 steps: 20.53 steps/s)
# Timing step 2500: 123.14s (49.26 ms/step | 20.30 steps/s | this 500 steps: 20.69 steps/s)
# Step 2999: scaling = -3.5980e-03, chi^2 = 8.2467e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 5.66 carbon-equivalents, 14.07 remaining
# Timing step 3000: 147.45s (49.15 ms/step | 20.35 steps/s | this 500 steps: 20.57 steps/s)
# Timing step 3500: 171.51s (49.00 ms/step | 20.41 steps/s | this 500 steps: 20.78 steps/s)
# Step 3999: scaling = -1.5434e-02, chi^2 = 1.0445e-02
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 9.81 carbon-equivalents, 12.74 remaining
# Timing step 4000: 195.49s (48.87 ms/step | 20.46 steps/s | this 500 steps: 20.86 steps/s)
# Timing step 4500: 219.39s (48.75 ms/step | 20.51 steps/s | this 500 steps: 20.92 steps/s)
# Step 4999: scaling = -7.4843e-03, chi^2 = 8.0711e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 7.87 carbon-equivalents, 13.59 remaining
# Timing step 5000: 243.84s (48.77 ms/step | 20.50 steps/s | this 500 steps: 20.45 steps/s)
# Timing step 5500: 267.83s (48.70 ms/step | 20.54 steps/s | this 500 steps: 20.84 steps/s)
# Step 5999: scaling = -3.4387e-04, chi^2 = 7.8606e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 7.97 carbon-equivalents, 13.67 remaining
# Timing step 6000: 291.73s (48.62 ms/step | 20.57 steps/s | this 500 steps: 20.92 steps/s)
# Timing step 6500: 316.16s (48.64 ms/step | 20.56 steps/s | this 500 steps: 20.47 steps/s)
# Step 6999: scaling = 9.5346e-04, chi^2 = 7.6022e-033
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 7.13 carbon-equivalents, 13.66 remaining
# Timing step 7000: 340.61s (48.66 ms/step | 20.55 steps/s | this 500 steps: 20.44 steps/s)
# Timing step 7500: 364.64s (48.62 ms/step | 20.57 steps/s | this 500 steps: 20.81 steps/s)
# Step 7999: scaling = 8.0016e-06, chi^2 = 7.3566e-033
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 6.82 carbon-equivalents, 13.44 remaining
# Timing step 8000: 389.06s (48.63 ms/step | 20.56 steps/s | this 500 steps: 20.48 steps/s)
# Timing step 8500: 413.96s (48.70 ms/step | 20.53 steps/s | this 500 steps: 20.07 steps/s)
# Step 8999: scaling = 1.2373e-03, chi^2 = 7.2137e-033
# Stray feature removal: Map has 7 blobs, removing 6 of them
# Zeroed 6.73 carbon-equivalents, 13.21 remaining
# Timing step 9000: 438.47s (48.72 ms/step | 20.53 steps/s | this 500 steps: 20.40 steps/s)
# Timing step 9500: 462.72s (48.71 ms/step | 20.53 steps/s | this 500 steps: 20.62 steps/s)
# Step 9999: scaling = -6.5854e-04, chi^2 = 7.2203e-03
# Stray feature removal: Map has 7 blobs, removing 6 of them
# Zeroed 6.63 carbon-equivalents, 13.56 remaining
# Timing step 10000: 487.01s (48.70 ms/step | 20.53 steps/s | this 500 steps: 20.58 steps/s)
# Step 10000: scaling = -1.0900e-03, chi^2 = 7.2176e-03
#
# ### Run 6 ###
# Elapsed time = 25.074 ms
# Initial scaling: 0.008
# Elapsed time = 102.987 ms
# 0.19522457656989434 43477.9136539433 0.10220752422467123 7795
# Timing step 500: 25.89s (51.78 ms/step | 19.31 steps/s | this 500 steps: 19.31 steps/s)
# Step  999: scaling = -1.9000e-03, chi^2 = 9.1426e-03
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 3.82 carbon-equivalents, 13.85 remaining
# Timing step 1000: 49.80s (49.80 ms/step | 20.08 steps/s | this 500 steps: 20.91 steps/s)
# Timing step 1500: 77.06s (51.37 ms/step | 19.47 steps/s | this 500 steps: 18.35 steps/s)
# Step 1999: scaling = -7.1644e-03, chi^2 = 8.2634e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.00 carbon-equivalents, 13.06 remaining
# Timing step 2000: 107.89s (53.95 ms/step | 18.54 steps/s | this 500 steps: 16.22 steps/s)
# Timing step 2500: 139.31s (55.72 ms/step | 17.95 steps/s | this 500 steps: 15.91 steps/s)
# Step 2999: scaling = -8.4649e-04, chi^2 = 7.7852e-03
# Stray feature removal: Map has 3 blobs, removing 2 of them
# Zeroed 3.01 carbon-equivalents, 13.92 remaining
# Timing step 3000: 170.33s (56.78 ms/step | 17.61 steps/s | this 500 steps: 16.12 steps/s)
# Timing step 3500: 201.26s (57.50 ms/step | 17.39 steps/s | this 500 steps: 16.17 steps/s)
# Step 3999: scaling = -1.1574e-02, chi^2 = 7.3947e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 3.04 carbon-equivalents, 13.40 remaining
# Timing step 4000: 232.37s (58.09 ms/step | 17.21 steps/s | this 500 steps: 16.07 steps/s)
# Timing step 4500: 263.73s (58.61 ms/step | 17.06 steps/s | this 500 steps: 15.94 steps/s)
# Step 4999: scaling = -1.0295e-03, chi^2 = 7.2755e-03
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 3.17 carbon-equivalents, 13.54 remaining
# Timing step 5000: 292.70s (58.54 ms/step | 17.08 steps/s | this 500 steps: 17.26 steps/s)
# Timing step 5500: 317.43s (57.71 ms/step | 17.33 steps/s | this 500 steps: 20.22 steps/s)
# Step 5999: scaling = -5.5294e-05, chi^2 = 7.0360e-03
# Stray feature removal: Map has 3 blobs, removing 2 of them
# Zeroed 3.38 carbon-equivalents, 13.49 remaining
# Timing step 6000: 343.08s (57.18 ms/step | 17.49 steps/s | this 500 steps: 19.49 steps/s)
# Timing step 6500: 368.22s (56.65 ms/step | 17.65 steps/s | this 500 steps: 19.89 steps/s)
# Step 6999: scaling = -1.1155e-03, chi^2 = 6.8819e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 3.64 carbon-equivalents, 13.44 remaining
# Timing step 7000: 393.13s (56.16 ms/step | 17.81 steps/s | this 500 steps: 20.07 steps/s)
# Timing step 7500: 417.73s (55.70 ms/step | 17.95 steps/s | this 500 steps: 20.33 steps/s)
# Step 7999: scaling = -2.1271e-03, chi^2 = 6.8564e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 3.28 carbon-equivalents, 13.41 remaining
# Timing step 8000: 442.19s (55.27 ms/step | 18.09 steps/s | this 500 steps: 20.44 steps/s)
# Timing step 8500: 466.50s (54.88 ms/step | 18.22 steps/s | this 500 steps: 20.57 steps/s)
# Step 8999: scaling = -1.7394e-03, chi^2 = 6.9126e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 3.57 carbon-equivalents, 13.20 remaining
# Timing step 9000: 491.46s (54.61 ms/step | 18.31 steps/s | this 500 steps: 20.03 steps/s)
# Timing step 9500: 516.78s (54.40 ms/step | 18.38 steps/s | this 500 steps: 19.75 steps/s)
# Step 9999: scaling = 2.7540e-04, chi^2 = 6.9028e-033
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 3.68 carbon-equivalents, 12.94 remaining
# Timing step 10000: 541.52s (54.15 ms/step | 18.47 steps/s | this 500 steps: 20.21 steps/s)
# Step 10000: scaling = -6.1971e-04, chi^2 = 6.9028e-03
#
# ### Run 7 ###
# Elapsed time = 26.188 ms
# Initial scaling: 0.009
# Elapsed time = 112.741 ms
# 0.19522457656989434 40759.530745562784 0.10351032500288879 7795
# Timing step 500: 26.44s (52.88 ms/step | 18.91 steps/s | this 500 steps: 18.91 steps/s)
# Step  999: scaling = -4.9346e-03, chi^2 = 8.2761e-03
# Stray feature removal: Map has 3 blobs, removing 2 of them
# Zeroed 2.10 carbon-equivalents, 13.70 remaining
# Timing step 1000: 51.08s (51.08 ms/step | 19.58 steps/s | this 500 steps: 20.30 steps/s)
# Timing step 1500: 75.50s (50.33 ms/step | 19.87 steps/s | this 500 steps: 20.47 steps/s)
# Step 1999: scaling = -2.3814e-03, chi^2 = 8.4207e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 4.57 carbon-equivalents, 12.61 remaining
# Timing step 2000: 100.14s (50.07 ms/step | 19.97 steps/s | this 500 steps: 20.29 steps/s)
# Timing step 2500: 124.80s (49.92 ms/step | 20.03 steps/s | this 500 steps: 20.28 steps/s)
# Step 2999: scaling = -5.2161e-03, chi^2 = 8.0625e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 3.61 carbon-equivalents, 13.08 remaining
# Timing step 3000: 148.99s (49.66 ms/step | 20.14 steps/s | this 500 steps: 20.67 steps/s)
# Timing step 3500: 172.98s (49.42 ms/step | 20.23 steps/s | this 500 steps: 20.84 steps/s)
# Step 3999: scaling = -8.9756e-03, chi^2 = 8.1280e-03
# Stray feature removal: Map has 5 blobs, removing 4 of them
# Zeroed 3.27 carbon-equivalents, 12.27 remaining
# Timing step 4000: 197.24s (49.31 ms/step | 20.28 steps/s | this 500 steps: 20.61 steps/s)
# Timing step 4500: 221.53s (49.23 ms/step | 20.31 steps/s | this 500 steps: 20.58 steps/s)
# Step 4999: scaling = -2.5000e-03, chi^2 = 7.7608e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 3.55 carbon-equivalents, 13.02 remaining
# Timing step 5000: 245.49s (49.10 ms/step | 20.37 steps/s | this 500 steps: 20.88 steps/s)
# Timing step 5500: 269.53s (49.00 ms/step | 20.41 steps/s | this 500 steps: 20.80 steps/s)
# Step 5999: scaling = -3.9556e-03, chi^2 = 7.3216e-03
# Stray feature removal: Map has 3 blobs, removing 2 of them
# Zeroed 3.41 carbon-equivalents, 13.12 remaining
# Timing step 6000: 293.69s (48.95 ms/step | 20.43 steps/s | this 500 steps: 20.70 steps/s)
# Timing step 6500: 318.05s (48.93 ms/step | 20.44 steps/s | this 500 steps: 20.52 steps/s)
# Step 6999: scaling = -8.1427e-04, chi^2 = 7.1640e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 3.71 carbon-equivalents, 13.20 remaining
# Timing step 7000: 342.08s (48.87 ms/step | 20.46 steps/s | this 500 steps: 20.81 steps/s)
# Timing step 7500: 366.50s (48.87 ms/step | 20.46 steps/s | this 500 steps: 20.48 steps/s)
# Step 7999: scaling = -2.1129e-04, chi^2 = 6.9830e-03
# Stray feature removal: Map has 3 blobs, removing 2 of them
# Zeroed 3.82 carbon-equivalents, 13.04 remaining
# Timing step 8000: 390.77s (48.85 ms/step | 20.47 steps/s | this 500 steps: 20.61 steps/s)
# Timing step 8500: 415.00s (48.82 ms/step | 20.48 steps/s | this 500 steps: 20.63 steps/s)
# Step 8999: scaling = 1.0160e-03, chi^2 = 7.1681e-033
# Stray feature removal: Map has 3 blobs, removing 2 of them
# Zeroed 3.41 carbon-equivalents, 13.20 remaining
# Timing step 9000: 439.19s (48.80 ms/step | 20.49 steps/s | this 500 steps: 20.67 steps/s)
# Timing step 9500: 463.21s (48.76 ms/step | 20.51 steps/s | this 500 steps: 20.81 steps/s)
# Step 9999: scaling = -4.4290e-04, chi^2 = 7.0057e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 3.41 carbon-equivalents, 13.25 remaining
# Timing step 10000: 487.96s (48.80 ms/step | 20.49 steps/s | this 500 steps: 20.20 steps/s)
# Step 10000: scaling = 3.9823e-04, chi^2 = 7.0052e-03
#
# ### Run 8 ###
# Elapsed time = 25.685 ms
# Initial scaling: 0.009
# Elapsed time = 109.655 ms
# 0.19522457656989434 39165.86322601558 0.10330141153506539 7795
# Timing step 500: 25.72s (51.44 ms/step | 19.44 steps/s | this 500 steps: 19.44 steps/s)
# Step  999: scaling = -1.4127e-02, chi^2 = 1.2454e-02
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 10.97 carbon-equivalents, 10.22 remaining
# Timing step 1000: 50.40s (50.40 ms/step | 19.84 steps/s | this 500 steps: 20.26 steps/s)
# Timing step 1500: 75.75s (50.50 ms/step | 19.80 steps/s | this 500 steps: 19.72 steps/s)
# Step 1999: scaling = -1.9305e-02, chi^2 = 9.6255e-03
# Stray feature removal: Map has 8 blobs, removing 7 of them
# Zeroed 5.26 carbon-equivalents, 14.37 remaining
# Timing step 2000: 100.14s (50.07 ms/step | 19.97 steps/s | this 500 steps: 20.50 steps/s)
# Timing step 2500: 124.52s (49.81 ms/step | 20.08 steps/s | this 500 steps: 20.51 steps/s)
# Step 2999: scaling = -1.1073e-02, chi^2 = 9.3205e-03
# Stray feature removal: Map has 6 blobs, removing 5 of them
# Zeroed 4.18 carbon-equivalents, 13.72 remaining
# Timing step 3000: 148.66s (49.55 ms/step | 20.18 steps/s | this 500 steps: 20.71 steps/s)
# Timing step 3500: 172.80s (49.37 ms/step | 20.25 steps/s | this 500 steps: 20.71 steps/s)
# Step 3999: scaling = -1.5740e-02, chi^2 = 8.5806e-03
# Stray feature removal: Map has 4 blobs, removing 3 of them
# Zeroed 4.18 carbon-equivalents, 13.35 remaining
# Timing step 4000: 196.77s (49.19 ms/step | 20.33 steps/s | this 500 steps: 20.87 steps/s)
# Timing step 4500: 220.99s (49.11 ms/step | 20.36 steps/s | this 500 steps: 20.64 steps/s)
# Step 4999: scaling = -3.5089e-03, chi^2 = 8.7871e-03
# Stray feature removal: Map has 10 blobs, removing 9 of them
# Zeroed 5.37 carbon-equivalents, 12.74 remaining
# Timing step 5000: 245.09s (49.02 ms/step | 20.40 steps/s | this 500 steps: 20.75 steps/s)
# Timing step 5500: 269.04s (48.92 ms/step | 20.44 steps/s | this 500 steps: 20.88 steps/s)
# Step 5999: scaling = 1.4402e-04, chi^2 = 8.5026e-033
# Stray feature removal: Map has 13 blobs, removing 12 of them
# Zeroed 4.75 carbon-equivalents, 13.04 remaining
# Timing step 6000: 293.07s (48.84 ms/step | 20.47 steps/s | this 500 steps: 20.81 steps/s)
# Timing step 6500: 317.30s (48.82 ms/step | 20.49 steps/s | this 500 steps: 20.63 steps/s)
# Step 6999: scaling = -4.2681e-04, chi^2 = 8.0509e-03
# Stray feature removal: Map has 15 blobs, removing 14 of them
# Zeroed 4.83 carbon-equivalents, 12.84 remaining
# Timing step 7000: 341.08s (48.73 ms/step | 20.52 steps/s | this 500 steps: 21.03 steps/s)
# Timing step 7500: 365.28s (48.70 ms/step | 20.53 steps/s | this 500 steps: 20.66 steps/s)
# Step 7999: scaling = -4.1576e-04, chi^2 = 7.7948e-03
# Stray feature removal: Map has 11 blobs, removing 10 of them
# Zeroed 4.49 carbon-equivalents, 12.59 remaining
# Timing step 8000: 389.13s (48.64 ms/step | 20.56 steps/s | this 500 steps: 20.96 steps/s)
# Timing step 8500: 413.82s (48.68 ms/step | 20.54 steps/s | this 500 steps: 20.25 steps/s)
# Step 8999: scaling = 2.5064e-04, chi^2 = 7.6023e-033
# Stray feature removal: Map has 11 blobs, removing 10 of them
# Zeroed 8.01 carbon-equivalents, 9.40 remaining
# Timing step 9000: 438.03s (48.67 ms/step | 20.55 steps/s | this 500 steps: 20.65 steps/s)
# Timing step 9500: 463.05s (48.74 ms/step | 20.52 steps/s | this 500 steps: 19.99 steps/s)
# Step 9999: scaling = 6.4041e-04, chi^2 = 7.5139e-033
# Stray feature removal: Map has 12 blobs, removing 11 of them
# Zeroed 8.40 carbon-equivalents, 9.58 remaining
# Timing step 10000: 488.41s (48.84 ms/step | 20.47 steps/s | this 500 steps: 19.72 steps/s)
# Step 10000: scaling = -1.9829e-04, chi^2 = 7.5139e-03
#
# ### Run 9 ###
# Elapsed time = 23.754 ms
# Initial scaling: 0.009
# Elapsed time = 104.539 ms
# 0.19522457656989434 39971.37778153936 0.10154503411799683 7795
# Timing step 500: 26.46s (52.92 ms/step | 18.90 steps/s | this 500 steps: 18.90 steps/s)
# Step  999: scaling = -1.0031e-02, chi^2 = 9.8198e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 3.32 carbon-equivalents, 13.77 remaining
# Timing step 1000: 52.57s (52.57 ms/step | 19.02 steps/s | this 500 steps: 19.15 steps/s)
# Timing step 1500: 77.58s (51.72 ms/step | 19.34 steps/s | this 500 steps: 19.99 steps/s)
# Step 1999: scaling = -2.7912e-02, chi^2 = 1.1595e-02
# Stray feature removal: Map has 11 blobs, removing 10 of them
# Zeroed 4.25 carbon-equivalents, 13.82 remaining
# Timing step 2000: 102.06s (51.03 ms/step | 19.60 steps/s | this 500 steps: 20.42 steps/s)
# Timing step 2500: 127.22s (50.89 ms/step | 19.65 steps/s | this 500 steps: 19.88 steps/s)
# Step 2999: scaling = -1.2534e-03, chi^2 = 8.8050e-03
# Stray feature removal: Map has 10 blobs, removing 9 of them
# Zeroed 3.44 carbon-equivalents, 13.06 remaining
# Timing step 3000: 151.81s (50.60 ms/step | 19.76 steps/s | this 500 steps: 20.33 steps/s)
# Timing step 3500: 176.32s (50.38 ms/step | 19.85 steps/s | this 500 steps: 20.40 steps/s)
# Step 3999: scaling = -8.5083e-03, chi^2 = 9.6588e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 5.19 carbon-equivalents, 12.41 remaining
# Timing step 4000: 201.03s (50.26 ms/step | 19.90 steps/s | this 500 steps: 20.24 steps/s)
# Timing step 4500: 225.32s (50.07 ms/step | 19.97 steps/s | this 500 steps: 20.58 steps/s)
# Step 4999: scaling = -1.7760e-03, chi^2 = 7.6022e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 4.02 carbon-equivalents, 12.37 remaining
# Timing step 5000: 250.51s (50.10 ms/step | 19.96 steps/s | this 500 steps: 19.85 steps/s)
# Timing step 5500: 274.23s (49.86 ms/step | 20.06 steps/s | this 500 steps: 21.08 steps/s)
# Step 5999: scaling = -4.4314e-04, chi^2 = 7.1440e-03
# Stray feature removal: Map has 10 blobs, removing 9 of them
# Zeroed 4.04 carbon-equivalents, 12.81 remaining
# Timing step 6000: 298.58s (49.76 ms/step | 20.10 steps/s | this 500 steps: 20.54 steps/s)
# Timing step 6500: 322.71s (49.65 ms/step | 20.14 steps/s | this 500 steps: 20.72 steps/s)
# Step 6999: scaling = 5.4292e-04, chi^2 = 7.0510e-033
# Stray feature removal: Map has 11 blobs, removing 10 of them
# Zeroed 7.86 carbon-equivalents, 9.10 remaining
# Timing step 7000: 346.59s (49.51 ms/step | 20.20 steps/s | this 500 steps: 20.94 steps/s)
# Timing step 7500: 370.36s (49.38 ms/step | 20.25 steps/s | this 500 steps: 21.04 steps/s)
# Step 7999: scaling = -1.2927e-03, chi^2 = 6.9297e-03
# Stray feature removal: Map has 11 blobs, removing 10 of them
# Zeroed 7.56 carbon-equivalents, 8.84 remaining
# Timing step 8000: 394.39s (49.30 ms/step | 20.28 steps/s | this 500 steps: 20.81 steps/s)
# Timing step 8500: 418.23s (49.20 ms/step | 20.32 steps/s | this 500 steps: 20.97 steps/s)
# Step 8999: scaling = -2.2967e-03, chi^2 = 6.8981e-03
# Stray feature removal: Map has 9 blobs, removing 8 of them
# Zeroed 7.38 carbon-equivalents, 8.66 remaining
# Timing step 9000: 442.75s (49.19 ms/step | 20.33 steps/s | this 500 steps: 20.39 steps/s)
# Timing step 9500: 466.90s (49.15 ms/step | 20.35 steps/s | this 500 steps: 20.71 steps/s)
# Step 9999: scaling = -2.4434e-03, chi^2 = 6.7988e-03
# Stray feature removal: Map has 7 blobs, removing 6 of them
# Zeroed 8.19 carbon-equivalents, 7.13 remaining
# Timing step 10000: 490.89s (49.09 ms/step | 20.37 steps/s | this 500 steps: 20.84 steps/s)
# Step 10000: scaling = 1.0067e-03, chi^2 = 6.7963e-03

# %%
weight_list = np.array(weight_list)

# %%
weight_list.mean(0).shape
# Out:
# (27000,)

# %%
for idx, w in enumerate(weight_list):
    write_out(xyz, w, f'data/1U19/run{idx}.pdb')

# %%
write_out(xyz, weight_list.mean(0), 'data/1U19/run_average.pdb', grid='data/1U19/grid.pdb', op=allowed_points)

# %%
(1/np.array(chi_list)[:, None] * weight_list).sum(0) / (1/np.array(chi_list)).sum()
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
(1/np.array(chi_list)[:, None] * weight_list).sum(0).max()
# Out:
# 1009.1463466885056

# %%
1/np.array(chi_list)
# Out:
# array([ 148.43641575,  138.2698564 ,  139.8772334 , 1416.96147874,
#        3254.94925635,  138.55005766,  144.86939691,  142.75067552,
#         133.08739248,  147.13834829])

# %%
weighted_weight = (1/np.array(chi_list)[:, None] * weight_list).sum(0) / (1/np.array(chi_list)).sum()
write_out(xyz, weighted_weight, 'data/1U19/run_average_weighted.pdb', grid='data/1U19/grid.pdb', op=allowed_points)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(3, 1)
ax[0].plot(chi_trace)
ax[0].set_yscale('log')
ax[0].set_ylabel('chi2')
ax[1].plot(scale_trace,'.', markersize=2)
ax[1].set_ylabel('scaling')
ax[2].plot(np.array(fine_timing_trace)*1000,'.', markersize=2)
ax[2].set_ylabel('Timing (ms)')
# Out:
# Text(0, 0.5, 'Timing (ms)')

# %%
plt.plot(scatter.q, S_calc_all, label='target')
plt.yscale('log')
plt.plot(scatter.q, S_calc_pro_before, label='before')
plt.plot(scatter.q, final_S_calc, label='after')
# plt.plot(scatter.q, S_calc_trial, label='chain B')
# plt.plot(scatter.q, S_calc_cross, label='chain A x chain B')
# plt.plot(scatter.q, S_calc_pro + S_calc_trial + 2 * S_calc_cross, label='trial')
plt.legend()

# %%
# plt.plot(scatter.q, S_calc_all, label='target')
# plt.yscale('log')
plt.plot(scatter.q, S_calc_all -S_calc_pro_before, label='before')
plt.plot(scatter.q, S_calc_all - final_S_calc, label='after')
# plt.plot(scatter.q, S_calc_trial, label='chain B')
# plt.plot(scatter.q, S_calc_cross, label='chain A x chain B')
# plt.plot(scatter.q, S_calc_pro + S_calc_trial + 2 * S_calc_cross, label='separate')
plt.legend()

# %%
write_out(xyz, weight, 'test.pdb', grid='grid.pdb', op=op)

# %%
import matplotlib.pyplot as plt
plt.plot(scatter.q, (S_calc_all - S_calc_pro) / S_calc_all)
