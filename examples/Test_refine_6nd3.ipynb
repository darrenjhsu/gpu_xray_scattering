# %%
import numpy as np
from gpu_xray_scattering import XS
from gpu_xray_scattering.Molecule import Molecule
import glob
import MDAnalysis as mda
from MDAnalysis.topology.guessers import guess_types
from scipy.ndimage import binary_erosion, binary_dilation
import numpy.polynomial.polynomial as poly

def readPDB(fname, sel='protein', sel2=None, psf=None):
    if psf is not None:
        U = mda.Universe(psf, fname)
    else:
        U = mda.Universe(fname)
    Usel = U.select_atoms(sel)
    try:
        print(Uele[:3])
        Uele = Usel.elements
    except:
        guessed_elements = guess_types(U.atoms.names)
        U.add_TopologyAttr('elements', guessed_elements)
        
    
    if sel2 is not None:
        Usel2 = U.select_atoms(sel2)
        return Usel.positions, Usel.elements, Usel2.positions, Usel2.elements
    else:
        return Usel.positions, Usel.elements

# %%
pro_coord1, pro_ele1, pro_coord2, pro_ele2 = readPDB('data/6ND3/6nd3.pdb', sel='protein', sel2='resname BTL')
pro_coord, pro_ele = readPDB('data/6ND3/6nd3.pdb', sel='protein or resname BTL')

# %%
# Create grid
def create_grid(coord, pad=1, spacing=0.5, minsize=None):
    # minsize is the side length of the box, can also be rectangular if input is a list/array of length 3
    # otherwise ignored
    minx, miny, minz = coord.min(0)
    maxx, maxy, maxz = coord.max(0)
    cenx, ceny, cenz = coord.min(0) + (coord.max(0) - coord.min(0)) / 2
    if minsize is not None:
        if np.isscalar(minsize):
            minx = np.min([minx, cenx - minsize / 2])
            miny = np.min([miny, ceny - minsize / 2])
            minz = np.min([minz, cenz - minsize / 2])
            maxx = np.max([maxx, cenx + minsize / 2])
            maxy = np.max([maxy, ceny + minsize / 2])
            maxz = np.max([maxz, cenz + minsize / 2])
        elif len(minsize) == 3:
            minx = np.min([minx, cenx - minsize[0] / 2])
            miny = np.min([miny, ceny - minsize[1] / 2])
            minz = np.min([minz, cenz - minsize[2] / 2])
            maxx = np.max([maxx, cenx + minsize[0] / 2])
            maxy = np.max([maxy, ceny + minsize[1] / 2])
            maxz = np.max([maxz, cenz + minsize[2] / 2])
        else:
            print(f"minsize is set as {minsize} but we don't know what to do with it")
    x_ = np.arange(minx - pad, maxx + pad, spacing)
    y_ = np.arange(miny - pad, maxy + pad, spacing)
    z_ = np.arange(minz - pad, maxz + pad, spacing)
    numx = len(x_)
    numy = len(y_)
    numz = len(z_)
    xyz = np.array([(x, y, z) for x in x_ for y in y_ for z in z_])
    xyzd = np.array((numx, numy, numz))
    print(f'Grid will be [{numx}, {numy}, {numz}] ({numx*numy*numz} elements)')
    return xyz, xyzd

# %%
spacing = 0.75
pad = 1
minsize = 20
xyz, xyzd = create_grid(pro_coord2, spacing=spacing, pad=pad, minsize=minsize)
# Out:
# Grid will be [30, 30, 30] (27000 elements)

# %%
def overlap(coord1, coord2, radius=1):
    # returns if points in coord2 overlaps with coord1 within radius
    return (((coord1[:, :, None] - coord2[:, :, None].T)**2).sum(1) < radius**2).sum(0) == 0

# %%
allowed_points = overlap(pro_coord1, xyz, radius=2)

# %%
allowed_points = allowed_points.reshape(xyzd)

# %%
allowed_origins = binary_erosion(allowed_points, iterations=int(2/spacing))

# %%
print(allowed_points.sum(), allowed_origins.sum())
# Out:
# 5770 77

# %%
def get_trial_sphere(xyz, allowed_origin, allowed_volume, dilation=2):
    # Returns a list of length len(allowed_origin) which includes points for trial
#     print(np.argwhere(allowed_origin))
    
    trial_list = []
    trial_idx = []
    for idx, (x, y, z) in enumerate(np.argwhere(allowed_origin)):
        vol = np.zeros_like(allowed_volume)
        if idx > 0 and idx % 1000 == 0:
            print(idx)
        vol[x, y, z] = True
        vol = binary_dilation(vol, iterations=dilation) * allowed_volume
        trial_list.append(xyz[np.argwhere(vol.ravel()).flatten()])
        trial_idx.append(np.argwhere(vol.ravel()).flatten())
#         print()
    print('done')
    return trial_list, trial_idx

# %%
trial_list, trial_idx = \
    get_trial_sphere(xyz, allowed_origins, allowed_points, dilation=int(2.5/spacing))
# Out:
# done

# %%
scatter = XS.Scatter(q=np.linspace(0.03, 1.2, num=160), use_oa=1)

# %%
pro_all = Molecule(coordinates=pro_coord, elements=pro_ele)
pro = Molecule(coordinates=pro_coord1, elements=pro_ele1)

# %%
S_calc_all = scatter.scatter(pro_all, timing=False)
S_calc_all = scatter.scatter(pro_all, timing=True)
S_calc_pro_before = scatter.scatter(pro, timing=False)
S_err = S_calc_all * 0.03
# Out:
# Elapsed time = 12.841 ms

# %%
# Solve for the scaling factor for trial density

def res_func_analytical(Idata, Iprior, Icross, Iguess, sigqdata):
    a = np.sum(2 * Icross * (Idata - Iprior) / sigqdata**2) # zeroth order term
    b = np.sum(-(4 * Icross**2 - 2 * Iguess * (Idata - Iprior)) / sigqdata**2)
    c = np.sum(-6 * Iguess * Icross / sigqdata**2)
    d = np.sum(-2 * Iguess**2 / sigqdata**2)
    eq = poly.Polynomial((a, b, c, d))
    roots = eq.roots()
#     print(f'analytical roots: {roots}')
    chi = np.inf
    root_best = 0
    for root_c in roots[np.isreal(roots)]:
        root = root_c.real
        chi_this = np.sum(((Idata - Iprior - Icross * 2 * root - Iguess * root * root) / sigqdata)**2)/Idata.size
        if chi_this < chi:
            chi = chi_this
            root_best = root
#     print(f'analytical gives {chi} at {root_best}')
    return root_best
# Add to weight
# Flatten negative weight

# %%
def write_pdb_line(f,*j):
    j = list(j)
    j[0] = j[0].ljust(6)#atom#6s
    j[1] = j[1].rjust(5)#aomnum#5d
    j[2] = j[2].center(4)#atomname$#4s
    j[3] = j[3].ljust(3)#resname#1s
    j[4] = j[4].rjust(1) #Astring
    j[5] = j[5].rjust(4) #resnum
    j[6] = str('%8.3f' % (float(j[6]))).rjust(8) #x
    j[7] = str('%8.3f' % (float(j[7]))).rjust(8)#y
    j[8] = str('%8.3f' % (float(j[8]))).rjust(8) #z\
    j[9] =str('%6.2f'%(float(j[9]))).rjust(6)#occ
    j[10]=str('%6.2f'%(float(j[10]))).ljust(6)#temp
    j[11]=j[11].rjust(12)#elname
    f.write("%s%s %s %s %s%s    %s%s%s%s%s%s\n"% (j[0],j[1],j[2],j[3],j[4],j[5],j[6],j[7],j[8],j[9],j[10],j[11]))
            
def write_out(xyz, weight, fname, grid=None, op=None, mode='w', save_space=True):
    with open(fname, mode) as f:
        for i_ in range(len(xyz)):
            if weight[i_] > 0 or not save_space:
                i = i_ + 1
                write_pdb_line(f,'ATOM', str(i), 'X', 'X', 'A', '1', *xyz[i_], weight[i_]*100, 1.0, 'X')
        f.write('END\n')

    if grid is not None:
        if op is not None:
            allowed = op.flatten()
        else:
            allowed = np.ones_like(weight)
        with open(grid, mode) as f:
            for i_ in range(len(xyz)):
#                 if weight[i_] > 0:
                    i = i_ + 1
                    write_pdb_line(f,'ATOM', str(i), 'X', 'X', 'A', '1', *xyz[i_], allowed[i_], 1.0, 'X')
            f.write('END\n')

# %%
import time
from scipy import ndimage
def refine(xyz, trial_list, op, S_calc_all, S_err, scatter,
           steps=10000,
           timing_step=500,
           flatten_step=100,
           connectivity_step=1000,
           weight_max=0.05,
           struct_connectivity_A=4,
           grid_spacing=0.75,
           start_refine=5000,
           do_trial=True,
           write_traj=None,
           write_fname=None,
           input_weight=None):
    
    n_origins = len(trial_list)
    if input_weight is None:
        weight = np.random.random(len(xyz))
        weight[~op.flatten()] = 0
        S_calc_pro, S_calc_trial, S_calc_cross = \
                scatter.cross_scatter(pro, prior=np.empty((0, 3)), weight_p=np.empty(0), 
                                      trial=xyz[op.flatten()], weight_t=weight[op.flatten()], timing=True)
        S_calc_pro_before = S_calc_pro.copy() # Initial curve

        chi_zero = (((S_calc_all - S_calc_pro) / S_err)**2).sum() / (len(S_calc_all) - 1)
        chi_before = (((S_calc_all - S_calc_pro - S_calc_trial - 2 * S_calc_cross) / S_err)**2).sum() / (len(S_calc_all) - 1)
        scaling = res_func_analytical(S_calc_all, S_calc_pro, S_calc_cross, S_calc_trial, S_err)
        print(f'Initial scaling: {scaling:.3f}')
        weight[op.flatten()] *= scaling
        weight_trial = weight.copy()
        S_calc_pro, _, _ = \
                scatter.cross_scatter(pro, prior=xyz, weight_p=weight, 
                                      trial=xyz, timing=True)
        chi_after = (((S_calc_all - S_calc_pro) / S_err)**2).sum() / (len(S_calc_all) - 1)
        print(chi_zero, chi_before, chi_after, (weight>0).sum())
    else:
        weight = input_weight
        
    chi_trace = []
    scale_trace = []
    fine_timing_trace = []


    timing_step = timing_step
    flatten_step = flatten_step
    connectivity_step = connectivity_step
    weight_max = weight_max
    struct_connectivity = int(struct_connectivity_A / spacing)
    start_refine = start_refine
    trial = do_trial
    write_traj = write_traj
    if trial:
        weight_trial = weight.copy()

    t0 = time.time()
    t01 = time.time()
    for idx in range(steps+1):

        choice = np.random.choice(np.arange(n_origins))
        if idx > start_refine:
            while (weight[trial_idx[choice]] > 0).sum() < len(trial_idx[choice]) / 2:
                # limit sampling to near existing density
                choice = np.random.choice(np.arange(n_origins))
        S_calc_pro, S_calc_trial, S_calc_cross = \
            scatter.cross_scatter(pro, prior=xyz[weight > 0], weight_p=weight[weight > 0], 
                                  trial=trial_list[choice], timing=False)
        chi_before = (((S_calc_all - S_calc_pro) / S_err)**2).sum() / (len(S_calc_all) - 1)
        scaling = res_func_analytical(S_calc_all, S_calc_pro, S_calc_cross, S_calc_trial, S_err)



        if trial:
            # Risk of increasing chi^2, so recalc 
            weight_trial[trial_idx[choice]] += scaling
            weight_trial[weight_trial<0] = 0
            S_calc_pro, S_calc_trial, S_calc_cross = \
                scatter.cross_scatter(pro, prior=xyz[weight_trial > 0], weight_p=weight_trial[weight_trial > 0], 
                                      trial=trial_list[choice], timing=False)
            chi_after = (((S_calc_all - S_calc_pro) / S_err)**2).sum() / (len(S_calc_all) - 1)

            if chi_after < chi_before:
                weight = weight_trial.copy()
                scale_trace.append(scaling)
            else:
                weight_trial = weight.copy()
                scale_trace.append(np.nan)
            chi = min(chi_after, chi_before)
        else:
            chi = chi_before
            scale_trace.append(scaling)
            weight[trial_idx[choice]] += scaling
            weight[weight<0] = 0

        chi_trace.append(chi)    

        if flatten_step is not None and idx > 0 and idx % flatten_step == 0:
            # flatten
            weight[weight < weight.max() * weight_max] = 0

        if connectivity_step is not None and idx > 0 and idx % connectivity_step == 0:
            # Pick largest feature
            struct = ndimage.generate_binary_structure(3, struct_connectivity)
            labeled_support, num_features = ndimage.label(weight.reshape(op.shape), structure=struct)
            labeled_support = labeled_support.flatten()
            sums = np.zeros((num_features))

            #find the feature with the greatest number of electrons
            for feature in range(num_features+1):
                sums[feature-1] = np.sum(weight[labeled_support==feature])
            big_feature = np.argmax(sums)+1

            #remove features from the support that are not the primary feature
            weight[labeled_support != big_feature] = 0
            print()
            print(f'Stray feature removal: Map has {num_features} blobs, removing {num_features-1} of them')
            print(f'Zeroed {sums.sum() - np.max(sums):.2f} carbon-equivalents, {np.max(sums):.2f} remaining')

        if write_traj is not None and idx > 0 and idx % write_traj == 0:
            if idx == write_traj:
                write_out(xyz, weight, 'traj.pdb', mode='w', save_space=False)
            else:
                write_out(xyz, weight, 'traj.pdb', mode='a', save_space=False)


        if timing_step is not None and idx > 0 and idx % timing_step == 0:
            t1 = time.time()
            if idx == timing_step:
                t2 = t0
            print(f'Timing step {idx}: {(t1 - t0):.2f}s ({(t1-t0)/idx*1000:.2f} ms/step | {idx/(t1-t0):.2f} steps/s | ', end='')
            print(f'this {timing_step} steps: {timing_step/(t1-t2):.2f} steps/s)')
            t2 = time.time()

        print(f'Step {idx:4d}: scaling = {scaling:.4e}, chi^2 = {chi:.4e}', end='\r')
        t00 = time.time()
        fine_timing_trace.append(t00 - t01)
        t01 = time.time()
    final_S_calc, _ , _ = \
            scatter.cross_scatter(pro, prior=xyz[weight_trial > 0], weight_p=weight_trial[weight_trial > 0], 
                                  trial=trial_list[choice], timing=False)
    return weight, chi_trace, scale_trace, fine_timing_trace, final_S_calc

# %%
weight_list = []
chi_list = []
for idx in range(10):
    print(f'\n\n### Run {idx} ###')
    weight, chi_trace, scale_trace, fine_timing_trace, final_S_calc = \
        refine(xyz, trial_list, allowed_points, S_calc_all, S_err, scatter, grid_spacing=spacing,
               steps=10000)#, input_weight=weight.copy())
    weight_list.append(weight)
    chi_list.append(chi_trace[-1])
# Out:
# ### Run 0 ###
# Elapsed time = 36.890 ms
# Initial scaling: 0.004
# Elapsed time = 116.145 ms
# 0.04962979914928057 10406.192716933356 0.0336018755512447 5770
# Timing step 500: 17.37s (34.74 ms/step | 28.79 steps/s | this 500 steps: 28.79 steps/s)
# Step  999: scaling = 5.4158e-05, chi^2 = 4.2723e-044
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.07 carbon-equivalents, 7.43 remaining
# Timing step 1000: 32.00s (32.00 ms/step | 31.25 steps/s | this 500 steps: 34.18 steps/s)
# Timing step 1500: 46.18s (30.78 ms/step | 32.48 steps/s | this 500 steps: 35.26 steps/s)
# Step 1999: scaling = -6.8700e-03, chi^2 = 3.2534e-04
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.01 carbon-equivalents, 7.42 remaining
# Timing step 2000: 60.34s (30.17 ms/step | 33.15 steps/s | this 500 steps: 35.32 steps/s)
# Timing step 2500: 74.52s (29.81 ms/step | 33.55 steps/s | this 500 steps: 35.24 steps/s)
# Step 2999: scaling = -5.4755e-03, chi^2 = 2.6978e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.44 remaining
# Timing step 3000: 88.60s (29.53 ms/step | 33.86 steps/s | this 500 steps: 35.53 steps/s)
# Timing step 3500: 103.41s (29.55 ms/step | 33.85 steps/s | this 500 steps: 33.76 steps/s)
# Step 3999: scaling = -4.1509e-03, chi^2 = 2.4777e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.38 remaining
# Timing step 4000: 117.91s (29.48 ms/step | 33.92 steps/s | this 500 steps: 34.48 steps/s)
# Timing step 4500: 133.58s (29.69 ms/step | 33.69 steps/s | this 500 steps: 31.90 steps/s)
# Step 4999: scaling = -4.9799e-03, chi^2 = 2.2044e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.43 remaining
# Timing step 5000: 149.08s (29.82 ms/step | 33.54 steps/s | this 500 steps: 32.26 steps/s)
# Timing step 5500: 164.52s (29.91 ms/step | 33.43 steps/s | this 500 steps: 32.39 steps/s)
# Step 5999: scaling = -3.4926e-04, chi^2 = 1.9541e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.41 remaining
# Timing step 6000: 179.09s (29.85 ms/step | 33.50 steps/s | this 500 steps: 34.32 steps/s)
# Timing step 6500: 194.71s (29.95 ms/step | 33.38 steps/s | this 500 steps: 32.01 steps/s)
# Step 6999: scaling = -7.8311e-05, chi^2 = 1.7056e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.55 remaining
# Timing step 7000: 209.86s (29.98 ms/step | 33.36 steps/s | this 500 steps: 32.99 steps/s)
# Timing step 7500: 225.09s (30.01 ms/step | 33.32 steps/s | this 500 steps: 32.82 steps/s)
# Step 7999: scaling = 1.2125e-04, chi^2 = 1.5811e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.49 remaining
# Timing step 8000: 239.90s (29.99 ms/step | 33.35 steps/s | this 500 steps: 33.78 steps/s)
# Timing step 8500: 254.53s (29.95 ms/step | 33.39 steps/s | this 500 steps: 34.16 steps/s)
# Step 8999: scaling = -1.5362e-04, chi^2 = 1.4085e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.47 remaining
# Timing step 9000: 269.06s (29.90 ms/step | 33.45 steps/s | this 500 steps: 34.43 steps/s)
# Timing step 9500: 283.98s (29.89 ms/step | 33.45 steps/s | this 500 steps: 33.51 steps/s)
# Step 9999: scaling = -2.9964e-06, chi^2 = 1.3352e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.46 remaining
# Timing step 10000: 298.60s (29.86 ms/step | 33.49 steps/s | this 500 steps: 34.20 steps/s)
# Step 10000: scaling = -8.9360e-04, chi^2 = 1.3346e-04
#
# ### Run 1 ###
# Elapsed time = 20.698 ms
# Initial scaling: 0.004
# Elapsed time = 100.241 ms
# 0.04962979914928057 10273.94092056257 0.03310136217027741 5770
# Timing step 500: 16.76s (33.53 ms/step | 29.83 steps/s | this 500 steps: 29.83 steps/s)
# Step  999: scaling = -3.6595e-03, chi^2 = 5.0628e-04
# Stray feature removal: Map has 3 blobs, removing 2 of them
# Zeroed 0.20 carbon-equivalents, 7.61 remaining
# Timing step 1000: 31.08s (31.08 ms/step | 32.17 steps/s | this 500 steps: 34.92 steps/s)
# Timing step 1500: 45.68s (30.46 ms/step | 32.83 steps/s | this 500 steps: 34.25 steps/s)
# Step 1999: scaling = -1.5327e-03, chi^2 = 3.3751e-04
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.08 carbon-equivalents, 7.41 remaining
# Timing step 2000: 60.54s (30.27 ms/step | 33.04 steps/s | this 500 steps: 33.66 steps/s)
# Timing step 2500: 75.13s (30.05 ms/step | 33.28 steps/s | this 500 steps: 34.28 steps/s)
# Step 2999: scaling = -4.0575e-03, chi^2 = 2.3605e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.37 remaining
# Timing step 3000: 89.64s (29.88 ms/step | 33.47 steps/s | this 500 steps: 34.45 steps/s)
# Timing step 3500: 104.28s (29.79 ms/step | 33.56 steps/s | this 500 steps: 34.15 steps/s)
# Step 3999: scaling = -4.3582e-03, chi^2 = 2.0653e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.49 remaining
# Timing step 4000: 118.76s (29.69 ms/step | 33.68 steps/s | this 500 steps: 34.52 steps/s)
# Timing step 4500: 133.46s (29.66 ms/step | 33.72 steps/s | this 500 steps: 34.02 steps/s)
# Step 4999: scaling = -4.3865e-03, chi^2 = 1.8607e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.59 remaining
# Timing step 5000: 148.23s (29.65 ms/step | 33.73 steps/s | this 500 steps: 33.85 steps/s)
# Timing step 5500: 162.98s (29.63 ms/step | 33.75 steps/s | this 500 steps: 33.91 steps/s)
# Step 5999: scaling = -8.1766e-04, chi^2 = 1.7098e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.63 remaining
# Timing step 6000: 177.36s (29.56 ms/step | 33.83 steps/s | this 500 steps: 34.75 steps/s)
# Timing step 6500: 192.27s (29.58 ms/step | 33.81 steps/s | this 500 steps: 33.54 steps/s)
# Step 6999: scaling = -6.0357e-05, chi^2 = 1.6369e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.60 remaining
# Timing step 7000: 206.72s (29.53 ms/step | 33.86 steps/s | this 500 steps: 34.62 steps/s)
# Timing step 7500: 221.59s (29.54 ms/step | 33.85 steps/s | this 500 steps: 33.62 steps/s)
# Step 7999: scaling = 2.1466e-04, chi^2 = 1.5642e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.48 remaining
# Timing step 8000: 236.54s (29.57 ms/step | 33.82 steps/s | this 500 steps: 33.43 steps/s)
# Timing step 8500: 251.12s (29.54 ms/step | 33.85 steps/s | this 500 steps: 34.31 steps/s)
# Step 8999: scaling = -1.5869e-04, chi^2 = 1.4709e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.46 remaining
# Timing step 9000: 265.69s (29.52 ms/step | 33.87 steps/s | this 500 steps: 34.31 steps/s)
# Timing step 9500: 280.48s (29.52 ms/step | 33.87 steps/s | this 500 steps: 33.81 steps/s)
# Step 9999: scaling = -1.5364e-04, chi^2 = 1.4025e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.44 remaining
# Timing step 10000: 294.69s (29.47 ms/step | 33.93 steps/s | this 500 steps: 35.17 steps/s)
# Step 10000: scaling = -2.6286e-08, chi^2 = 1.4025e-04
#
# ### Run 2 ###
# Elapsed time = 20.258 ms
# Initial scaling: 0.004
# Elapsed time = 101.270 ms
# 0.04962979914928057 11206.73766473242 0.03315570252571555 5770
# Timing step 500: 17.23s (34.46 ms/step | 29.02 steps/s | this 500 steps: 29.02 steps/s)
# Step  999: scaling = -3.7284e-03, chi^2 = 4.7213e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.25 remaining
# Timing step 1000: 31.94s (31.94 ms/step | 31.31 steps/s | this 500 steps: 34.00 steps/s)
# Timing step 1500: 46.92s (31.28 ms/step | 31.97 steps/s | this 500 steps: 33.37 steps/s)
# Step 1999: scaling = -4.5049e-03, chi^2 = 3.2754e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.41 remaining
# Timing step 2000: 61.65s (30.83 ms/step | 32.44 steps/s | this 500 steps: 33.94 steps/s)
# Timing step 2500: 76.52s (30.61 ms/step | 32.67 steps/s | this 500 steps: 33.62 steps/s)
# Step 2999: scaling = -5.5893e-03, chi^2 = 2.7127e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.36 remaining
# Timing step 3000: 91.62s (30.54 ms/step | 32.75 steps/s | this 500 steps: 33.13 steps/s)
# Timing step 3500: 106.13s (30.32 ms/step | 32.98 steps/s | this 500 steps: 34.45 steps/s)
# Step 3999: scaling = 7.6007e-05, chi^2 = 2.4460e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.55 remaining
# Timing step 4000: 120.68s (30.17 ms/step | 33.15 steps/s | this 500 steps: 34.36 steps/s)
# Timing step 4500: 135.02s (30.00 ms/step | 33.33 steps/s | this 500 steps: 34.87 steps/s)
# Step 4999: scaling = 5.1253e-05, chi^2 = 2.2484e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.68 remaining
# Timing step 5000: 149.15s (29.83 ms/step | 33.52 steps/s | this 500 steps: 35.40 steps/s)
# Timing step 5500: 163.52s (29.73 ms/step | 33.63 steps/s | this 500 steps: 34.77 steps/s)
# Step 5999: scaling = -2.5474e-04, chi^2 = 2.0998e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.63 remaining
# Timing step 6000: 177.72s (29.62 ms/step | 33.76 steps/s | this 500 steps: 35.22 steps/s)
# Timing step 6500: 192.23s (29.57 ms/step | 33.81 steps/s | this 500 steps: 34.47 steps/s)
# Step 6999: scaling = -5.9656e-04, chi^2 = 1.9509e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.66 remaining
# Timing step 7000: 206.69s (29.53 ms/step | 33.87 steps/s | this 500 steps: 34.56 steps/s)
# Timing step 7500: 220.93s (29.46 ms/step | 33.95 steps/s | this 500 steps: 35.13 steps/s)
# Step 7999: scaling = -8.7963e-04, chi^2 = 1.8378e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.64 remaining
# Timing step 8000: 235.64s (29.46 ms/step | 33.95 steps/s | this 500 steps: 33.97 steps/s)
# Timing step 8500: 250.25s (29.44 ms/step | 33.97 steps/s | this 500 steps: 34.22 steps/s)
# Step 8999: scaling = -2.3883e-04, chi^2 = 1.7772e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.65 remaining
# Timing step 9000: 264.76s (29.42 ms/step | 33.99 steps/s | this 500 steps: 34.46 steps/s)
# Timing step 9500: 279.71s (29.44 ms/step | 33.96 steps/s | this 500 steps: 33.45 steps/s)
# Step 9999: scaling = 1.7014e-07, chi^2 = 1.7097e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.63 remaining
# Timing step 10000: 294.39s (29.44 ms/step | 33.97 steps/s | this 500 steps: 34.07 steps/s)
# Step 10000: scaling = -1.4849e-04, chi^2 = 1.7097e-04
#
# ### Run 3 ###
# Elapsed time = 22.013 ms
# Initial scaling: 0.004
# Elapsed time = 100.916 ms
# 0.04962979914928057 10381.752481761878 0.03318619445870456 5770
# Timing step 500: 17.05s (34.11 ms/step | 29.32 steps/s | this 500 steps: 29.32 steps/s)
# Step  999: scaling = -8.0920e-04, chi^2 = 4.1591e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.36 remaining
# Timing step 1000: 32.55s (32.55 ms/step | 30.72 steps/s | this 500 steps: 32.26 steps/s)
# Timing step 1500: 47.57s (31.71 ms/step | 31.53 steps/s | this 500 steps: 33.28 steps/s)
# Step 1999: scaling = -6.2387e-03, chi^2 = 3.2647e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.39 remaining
# Timing step 2000: 62.09s (31.04 ms/step | 32.21 steps/s | this 500 steps: 34.44 steps/s)
# Timing step 2500: 76.58s (30.63 ms/step | 32.65 steps/s | this 500 steps: 34.50 steps/s)
# Step 2999: scaling = 4.5637e-04, chi^2 = 2.5670e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.26 remaining
# Timing step 3000: 91.27s (30.42 ms/step | 32.87 steps/s | this 500 steps: 34.05 steps/s)
# Timing step 3500: 106.05s (30.30 ms/step | 33.00 steps/s | this 500 steps: 33.82 steps/s)
# Step 3999: scaling = -3.6241e-03, chi^2 = 2.1388e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.19 remaining
# Timing step 4000: 120.95s (30.24 ms/step | 33.07 steps/s | this 500 steps: 33.56 steps/s)
# Timing step 4500: 135.41s (30.09 ms/step | 33.23 steps/s | this 500 steps: 34.59 steps/s)
# Step 4999: scaling = -5.1851e-03, chi^2 = 1.9006e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.26 remaining
# Timing step 5000: 149.92s (29.98 ms/step | 33.35 steps/s | this 500 steps: 34.45 steps/s)
# Timing step 5500: 164.66s (29.94 ms/step | 33.40 steps/s | this 500 steps: 33.93 steps/s)
# Step 5999: scaling = -3.6602e-04, chi^2 = 1.5913e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.45 remaining
# Timing step 6000: 179.07s (29.84 ms/step | 33.51 steps/s | this 500 steps: 34.70 steps/s)
# Timing step 6500: 193.52s (29.77 ms/step | 33.59 steps/s | this 500 steps: 34.59 steps/s)
# Step 6999: scaling = -9.0305e-05, chi^2 = 1.4765e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.44 remaining
# Timing step 7000: 208.47s (29.78 ms/step | 33.58 steps/s | this 500 steps: 33.44 steps/s)
# Timing step 7500: 223.30s (29.77 ms/step | 33.59 steps/s | this 500 steps: 33.72 steps/s)
# Step 7999: scaling = -2.1808e-05, chi^2 = 1.3860e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.36 remaining
# Timing step 8000: 238.14s (29.77 ms/step | 33.59 steps/s | this 500 steps: 33.69 steps/s)
# Timing step 8500: 252.57s (29.71 ms/step | 33.65 steps/s | this 500 steps: 34.65 steps/s)
# Step 8999: scaling = 3.3552e-05, chi^2 = 1.3024e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.35 remaining
# Timing step 9000: 267.20s (29.69 ms/step | 33.68 steps/s | this 500 steps: 34.18 steps/s)
# Timing step 9500: 281.89s (29.67 ms/step | 33.70 steps/s | this 500 steps: 34.03 steps/s)
# Step 9999: scaling = -6.2791e-05, chi^2 = 1.2471e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.26 remaining
# Timing step 10000: 296.48s (29.65 ms/step | 33.73 steps/s | this 500 steps: 34.29 steps/s)
# Step 10000: scaling = 8.7663e-05, chi^2 = 1.2468e-04
#
# ### Run 4 ###
# Elapsed time = 20.202 ms
# Initial scaling: 0.004
# Elapsed time = 103.947 ms
# 0.04962979914928057 11122.960986473554 0.033175392295317234 5770
# Timing step 500: 16.53s (33.05 ms/step | 30.25 steps/s | this 500 steps: 30.25 steps/s)
# Step  999: scaling = -3.7629e-03, chi^2 = 5.2556e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.53 remaining
# Timing step 1000: 30.94s (30.94 ms/step | 32.33 steps/s | this 500 steps: 34.70 steps/s)
# Timing step 1500: 45.29s (30.19 ms/step | 33.12 steps/s | this 500 steps: 34.84 steps/s)
# Step 1999: scaling = -7.1671e-03, chi^2 = 3.7132e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.49 remaining
# Timing step 2000: 59.72s (29.86 ms/step | 33.49 steps/s | this 500 steps: 34.63 steps/s)
# Timing step 2500: 74.19s (29.68 ms/step | 33.70 steps/s | this 500 steps: 34.56 steps/s)
# Step 2999: scaling = -4.3149e-03, chi^2 = 3.2447e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.49 remaining
# Timing step 3000: 89.42s (29.81 ms/step | 33.55 steps/s | this 500 steps: 32.83 steps/s)
# Timing step 3500: 104.40s (29.83 ms/step | 33.52 steps/s | this 500 steps: 33.38 steps/s)
# Step 3999: scaling = 1.7383e-04, chi^2 = 2.9379e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.48 remaining
# Timing step 4000: 119.36s (29.84 ms/step | 33.51 steps/s | this 500 steps: 33.43 steps/s)
# Timing step 4500: 134.18s (29.82 ms/step | 33.54 steps/s | this 500 steps: 33.74 steps/s)
# Step 4999: scaling = -1.7436e-03, chi^2 = 2.6313e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.48 remaining
# Timing step 5000: 148.69s (29.74 ms/step | 33.63 steps/s | this 500 steps: 34.46 steps/s)
# Timing step 5500: 163.09s (29.65 ms/step | 33.72 steps/s | this 500 steps: 34.72 steps/s)
# Step 5999: scaling = 1.9055e-05, chi^2 = 2.1817e-044
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.03 carbon-equivalents, 7.36 remaining
# Timing step 6000: 177.60s (29.60 ms/step | 33.78 steps/s | this 500 steps: 34.46 steps/s)
# Timing step 6500: 191.97s (29.53 ms/step | 33.86 steps/s | this 500 steps: 34.78 steps/s)
# Step 6999: scaling = -1.8602e-04, chi^2 = 1.9712e-04
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.03 carbon-equivalents, 7.41 remaining
# Timing step 7000: 206.75s (29.54 ms/step | 33.86 steps/s | this 500 steps: 33.83 steps/s)
# Timing step 7500: 221.38s (29.52 ms/step | 33.88 steps/s | this 500 steps: 34.18 steps/s)
# Step 7999: scaling = -9.0982e-05, chi^2 = 1.7429e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.43 remaining
# Timing step 8000: 235.96s (29.49 ms/step | 33.90 steps/s | this 500 steps: 34.30 steps/s)
# Timing step 8500: 250.32s (29.45 ms/step | 33.96 steps/s | this 500 steps: 34.80 steps/s)
# Step 8999: scaling = -2.6800e-06, chi^2 = 1.5620e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.51 remaining
# Timing step 9000: 265.19s (29.47 ms/step | 33.94 steps/s | this 500 steps: 33.63 steps/s)
# Timing step 9500: 280.15s (29.49 ms/step | 33.91 steps/s | this 500 steps: 33.41 steps/s)
# Step 9999: scaling = -2.1817e-04, chi^2 = 1.4033e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.53 remaining
# Timing step 10000: 295.06s (29.51 ms/step | 33.89 steps/s | this 500 steps: 33.54 steps/s)
# Step 10000: scaling = -7.1593e-05, chi^2 = 1.4032e-04
#
# ### Run 5 ###
# Elapsed time = 21.014 ms
# Initial scaling: 0.004
# Elapsed time = 103.984 ms
# 0.04962979914928057 10573.813781652198 0.03325898700654187 5770
# Timing step 500: 17.58s (35.16 ms/step | 28.44 steps/s | this 500 steps: 28.44 steps/s)
# Step  999: scaling = 2.2913e-04, chi^2 = 3.8162e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.27 remaining
# Timing step 1000: 32.44s (32.44 ms/step | 30.83 steps/s | this 500 steps: 33.66 steps/s)
# Timing step 1500: 46.89s (31.26 ms/step | 31.99 steps/s | this 500 steps: 34.61 steps/s)
# Step 1999: scaling = -5.4699e-03, chi^2 = 2.8010e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.32 remaining
# Timing step 2000: 61.37s (30.68 ms/step | 32.59 steps/s | this 500 steps: 34.52 steps/s)
# Timing step 2500: 75.75s (30.30 ms/step | 33.00 steps/s | this 500 steps: 34.76 steps/s)
# Step 2999: scaling = -2.7794e-03, chi^2 = 2.3933e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.41 remaining
# Timing step 3000: 90.14s (30.05 ms/step | 33.28 steps/s | this 500 steps: 34.75 steps/s)
# Timing step 3500: 104.57s (29.88 ms/step | 33.47 steps/s | this 500 steps: 34.66 steps/s)
# Step 3999: scaling = -4.9769e-04, chi^2 = 2.1062e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.56 remaining
# Timing step 4000: 118.97s (29.74 ms/step | 33.62 steps/s | this 500 steps: 34.71 steps/s)
# Timing step 4500: 133.28s (29.62 ms/step | 33.76 steps/s | this 500 steps: 34.95 steps/s)
# Step 4999: scaling = -4.4806e-03, chi^2 = 1.9364e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.57 remaining
# Timing step 5000: 147.65s (29.53 ms/step | 33.86 steps/s | this 500 steps: 34.80 steps/s)
# Timing step 5500: 161.96s (29.45 ms/step | 33.96 steps/s | this 500 steps: 34.93 steps/s)
# Step 5999: scaling = 8.0223e-05, chi^2 = 1.6861e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.54 remaining
# Timing step 6000: 176.40s (29.40 ms/step | 34.01 steps/s | this 500 steps: 34.62 steps/s)
# Timing step 6500: 190.76s (29.35 ms/step | 34.07 steps/s | this 500 steps: 34.83 steps/s)
# Step 6999: scaling = -1.4423e-04, chi^2 = 1.5187e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.54 remaining
# Timing step 7000: 205.18s (29.31 ms/step | 34.12 steps/s | this 500 steps: 34.66 steps/s)
# Timing step 7500: 219.59s (29.28 ms/step | 34.15 steps/s | this 500 steps: 34.71 steps/s)
# Step 7999: scaling = -6.9933e-05, chi^2 = 1.4187e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.48 remaining
# Timing step 8000: 233.99s (29.25 ms/step | 34.19 steps/s | this 500 steps: 34.71 steps/s)
# Timing step 8500: 248.36s (29.22 ms/step | 34.22 steps/s | this 500 steps: 34.81 steps/s)
# Step 8999: scaling = 2.8279e-05, chi^2 = 1.3222e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.47 remaining
# Timing step 9000: 262.71s (29.19 ms/step | 34.26 steps/s | this 500 steps: 34.84 steps/s)
# Timing step 9500: 277.05s (29.16 ms/step | 34.29 steps/s | this 500 steps: 34.86 steps/s)
# Step 9999: scaling = 1.4497e-06, chi^2 = 1.2477e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.45 remaining
# Timing step 10000: 291.39s (29.14 ms/step | 34.32 steps/s | this 500 steps: 34.88 steps/s)
# Step 10000: scaling = -2.4973e-05, chi^2 = 1.2477e-04
#
# ### Run 6 ###
# Elapsed time = 20.054 ms
# Initial scaling: 0.004
# Elapsed time = 116.301 ms
# 0.04962979914928057 10335.6416468905 0.03316103753593511 5770
# Timing step 500: 16.53s (33.06 ms/step | 30.25 steps/s | this 500 steps: 30.25 steps/s)
# Step  999: scaling = -6.2952e-03, chi^2 = 4.2164e-04
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.11 carbon-equivalents, 7.63 remaining
# Timing step 1000: 30.95s (30.95 ms/step | 32.31 steps/s | this 500 steps: 34.66 steps/s)
# Timing step 1500: 45.31s (30.21 ms/step | 33.11 steps/s | this 500 steps: 34.83 steps/s)
# Step 1999: scaling = -5.5320e-03, chi^2 = 3.1605e-04
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.11 carbon-equivalents, 7.54 remaining
# Timing step 2000: 59.68s (29.84 ms/step | 33.51 steps/s | this 500 steps: 34.80 steps/s)
# Timing step 2500: 74.10s (29.64 ms/step | 33.74 steps/s | this 500 steps: 34.67 steps/s)
# Step 2999: scaling = -1.6171e-03, chi^2 = 2.4500e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.57 remaining
# Timing step 3000: 88.50s (29.50 ms/step | 33.90 steps/s | this 500 steps: 34.73 steps/s)
# Timing step 3500: 102.86s (29.39 ms/step | 34.03 steps/s | this 500 steps: 34.81 steps/s)
# Step 3999: scaling = -5.0968e-03, chi^2 = 2.2677e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.50 remaining
# Timing step 4000: 117.20s (29.30 ms/step | 34.13 steps/s | this 500 steps: 34.87 steps/s)
# Timing step 4500: 131.65s (29.26 ms/step | 34.18 steps/s | this 500 steps: 34.60 steps/s)
# Step 4999: scaling = -3.3536e-03, chi^2 = 2.1671e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.55 remaining
# Timing step 5000: 146.00s (29.20 ms/step | 34.25 steps/s | this 500 steps: 34.85 steps/s)
# Timing step 5500: 160.34s (29.15 ms/step | 34.30 steps/s | this 500 steps: 34.87 steps/s)
# Step 5999: scaling = -4.9663e-04, chi^2 = 1.9580e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.48 remaining
# Timing step 6000: 174.92s (29.15 ms/step | 34.30 steps/s | this 500 steps: 34.30 steps/s)
# Timing step 6500: 189.36s (29.13 ms/step | 34.33 steps/s | this 500 steps: 34.61 steps/s)
# Step 6999: scaling = 1.7786e-04, chi^2 = 1.7676e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.53 remaining
# Timing step 7000: 203.79s (29.11 ms/step | 34.35 steps/s | this 500 steps: 34.66 steps/s)
# Timing step 7500: 218.16s (29.09 ms/step | 34.38 steps/s | this 500 steps: 34.80 steps/s)
# Step 7999: scaling = -3.7637e-04, chi^2 = 1.5811e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.57 remaining
# Timing step 8000: 232.54s (29.07 ms/step | 34.40 steps/s | this 500 steps: 34.77 steps/s)
# Timing step 8500: 246.98s (29.06 ms/step | 34.42 steps/s | this 500 steps: 34.62 steps/s)
# Step 8999: scaling = -1.1682e-04, chi^2 = 1.4512e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.53 remaining
# Timing step 9000: 261.34s (29.04 ms/step | 34.44 steps/s | this 500 steps: 34.81 steps/s)
# Timing step 9500: 275.81s (29.03 ms/step | 34.44 steps/s | this 500 steps: 34.56 steps/s)
# Step 9999: scaling = -4.4108e-04, chi^2 = 1.3609e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.51 remaining
# Timing step 10000: 290.15s (29.02 ms/step | 34.46 steps/s | this 500 steps: 34.86 steps/s)
# Step 10000: scaling = -1.4160e-05, chi^2 = 1.3609e-04
#
# ### Run 7 ###
# Elapsed time = 21.785 ms
# Initial scaling: 0.004
# Elapsed time = 101.022 ms
# 0.04962979914928057 10456.434101563524 0.03329613611226726 5770
# Timing step 500: 16.63s (33.25 ms/step | 30.07 steps/s | this 500 steps: 30.07 steps/s)
# Step  999: scaling = -7.2616e-03, chi^2 = 4.7559e-04
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.10 carbon-equivalents, 7.44 remaining
# Timing step 1000: 31.05s (31.05 ms/step | 32.21 steps/s | this 500 steps: 34.67 steps/s)
# Timing step 1500: 45.48s (30.32 ms/step | 32.98 steps/s | this 500 steps: 34.65 steps/s)
# Step 1999: scaling = -1.0404e-03, chi^2 = 3.5923e-04
# Stray feature removal: Map has 3 blobs, removing 2 of them
# Zeroed 0.10 carbon-equivalents, 7.40 remaining
# Timing step 2000: 59.88s (29.94 ms/step | 33.40 steps/s | this 500 steps: 34.73 steps/s)
# Timing step 2500: 74.31s (29.72 ms/step | 33.64 steps/s | this 500 steps: 34.64 steps/s)
# Step 2999: scaling = -5.6000e-03, chi^2 = 3.0434e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.46 remaining
# Timing step 3000: 88.67s (29.56 ms/step | 33.83 steps/s | this 500 steps: 34.82 steps/s)
# Timing step 3500: 103.04s (29.44 ms/step | 33.97 steps/s | this 500 steps: 34.80 steps/s)
# Step 3999: scaling = -3.9628e-03, chi^2 = 2.6314e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.40 remaining
# Timing step 4000: 117.39s (29.35 ms/step | 34.07 steps/s | this 500 steps: 34.84 steps/s)
# Timing step 4500: 131.77s (29.28 ms/step | 34.15 steps/s | this 500 steps: 34.77 steps/s)
# Step 4999: scaling = -8.3722e-04, chi^2 = 2.3773e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.51 remaining
# Timing step 5000: 146.02s (29.20 ms/step | 34.24 steps/s | this 500 steps: 35.10 steps/s)
# Timing step 5500: 160.62s (29.20 ms/step | 34.24 steps/s | this 500 steps: 34.25 steps/s)
# Step 5999: scaling = -6.4065e-04, chi^2 = 2.0625e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.49 remaining
# Timing step 6000: 174.62s (29.10 ms/step | 34.36 steps/s | this 500 steps: 35.70 steps/s)
# Timing step 6500: 188.64s (29.02 ms/step | 34.46 steps/s | this 500 steps: 35.68 steps/s)
# Step 6999: scaling = -1.3237e-04, chi^2 = 1.8561e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.49 remaining
# Timing step 7000: 202.72s (28.96 ms/step | 34.53 steps/s | this 500 steps: 35.52 steps/s)
# Timing step 7500: 217.21s (28.96 ms/step | 34.53 steps/s | this 500 steps: 34.49 steps/s)
# Step 7999: scaling = -4.4349e-05, chi^2 = 1.6588e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.50 remaining
# Timing step 8000: 231.78s (28.97 ms/step | 34.52 steps/s | this 500 steps: 34.33 steps/s)
# Timing step 8500: 246.00s (28.94 ms/step | 34.55 steps/s | this 500 steps: 35.17 steps/s)
# Step 8999: scaling = 5.0650e-05, chi^2 = 1.5667e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.50 remaining
# Timing step 9000: 260.15s (28.91 ms/step | 34.60 steps/s | this 500 steps: 35.32 steps/s)
# Timing step 9500: 274.16s (28.86 ms/step | 34.65 steps/s | this 500 steps: 35.70 steps/s)
# Step 9999: scaling = -9.6071e-05, chi^2 = 1.4836e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.55 remaining
# Timing step 10000: 288.33s (28.83 ms/step | 34.68 steps/s | this 500 steps: 35.28 steps/s)
# Step 10000: scaling = -1.5177e-04, chi^2 = 1.4836e-04
#
# ### Run 8 ###
# Elapsed time = 21.015 ms
# Initial scaling: 0.004
# Elapsed time = 105.447 ms
# 0.04962979914928057 10084.82267330019 0.033320298267425746 5770
# Timing step 500: 16.25s (32.51 ms/step | 30.76 steps/s | this 500 steps: 30.76 steps/s)
# Step  999: scaling = -6.8384e-03, chi^2 = 3.7621e-04
# Stray feature removal: Map has 2 blobs, removing 1 of them
# Zeroed 0.06 carbon-equivalents, 7.53 remaining
# Timing step 1000: 30.31s (30.31 ms/step | 32.99 steps/s | this 500 steps: 35.56 steps/s)
# Timing step 1500: 44.32s (29.54 ms/step | 33.85 steps/s | this 500 steps: 35.71 steps/s)
# Step 1999: scaling = 2.0391e-04, chi^2 = 3.1049e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.50 remaining
# Timing step 2000: 58.33s (29.17 ms/step | 34.29 steps/s | this 500 steps: 35.67 steps/s)
# Timing step 2500: 72.36s (28.94 ms/step | 34.55 steps/s | this 500 steps: 35.65 steps/s)
# Step 2999: scaling = -2.2712e-03, chi^2 = 2.7098e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.48 remaining
# Timing step 3000: 86.39s (28.80 ms/step | 34.72 steps/s | this 500 steps: 35.62 steps/s)
# Timing step 3500: 100.34s (28.67 ms/step | 34.88 steps/s | this 500 steps: 35.86 steps/s)
# Step 3999: scaling = -5.3213e-03, chi^2 = 2.5053e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.41 remaining
# Timing step 4000: 114.31s (28.58 ms/step | 34.99 steps/s | this 500 steps: 35.79 steps/s)
# Timing step 4500: 128.31s (28.51 ms/step | 35.07 steps/s | this 500 steps: 35.71 steps/s)
# Step 4999: scaling = -2.0983e-03, chi^2 = 2.4788e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.33 remaining
# Timing step 5000: 142.31s (28.46 ms/step | 35.13 steps/s | this 500 steps: 35.71 steps/s)
# Timing step 5500: 156.23s (28.40 ms/step | 35.21 steps/s | this 500 steps: 35.94 steps/s)
# Step 5999: scaling = 1.3035e-04, chi^2 = 2.0430e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.50 remaining
# Timing step 6000: 170.17s (28.36 ms/step | 35.26 steps/s | this 500 steps: 35.87 steps/s)
# Timing step 6500: 184.28s (28.35 ms/step | 35.27 steps/s | this 500 steps: 35.43 steps/s)
# Step 6999: scaling = 4.6162e-05, chi^2 = 1.7904e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.45 remaining
# Timing step 7000: 198.27s (28.32 ms/step | 35.30 steps/s | this 500 steps: 35.72 steps/s)
# Timing step 7500: 212.34s (28.31 ms/step | 35.32 steps/s | this 500 steps: 35.55 steps/s)
# Step 7999: scaling = 9.7751e-05, chi^2 = 1.6345e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.56 remaining
# Timing step 8000: 226.33s (28.29 ms/step | 35.35 steps/s | this 500 steps: 35.73 steps/s)
# Timing step 8500: 240.36s (28.28 ms/step | 35.36 steps/s | this 500 steps: 35.65 steps/s)
# Step 8999: scaling = -1.1008e-03, chi^2 = 1.4949e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.52 remaining
# Timing step 9000: 254.42s (28.27 ms/step | 35.37 steps/s | this 500 steps: 35.56 steps/s)
# Timing step 9500: 268.52s (28.27 ms/step | 35.38 steps/s | this 500 steps: 35.46 steps/s)
# Step 9999: scaling = -2.6768e-04, chi^2 = 1.3948e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.48 remaining
# Timing step 10000: 282.57s (28.26 ms/step | 35.39 steps/s | this 500 steps: 35.58 steps/s)
# Step 10000: scaling = -2.6724e-05, chi^2 = 1.3948e-04
#
# ### Run 9 ###
# Elapsed time = 22.017 ms
# Initial scaling: 0.004
# Elapsed time = 96.669 ms
# 0.04962979914928057 10531.327077442338 0.03331354175476624 5770
# Timing step 500: 16.14s (32.27 ms/step | 30.99 steps/s | this 500 steps: 30.99 steps/s)
# Step  999: scaling = -3.9320e-03, chi^2 = 3.0126e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.51 remaining
# Timing step 1000: 30.06s (30.06 ms/step | 33.27 steps/s | this 500 steps: 35.91 steps/s)
# Timing step 1500: 44.10s (29.40 ms/step | 34.02 steps/s | this 500 steps: 35.62 steps/s)
# Step 1999: scaling = -3.2037e-03, chi^2 = 2.3584e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.51 remaining
# Timing step 2000: 58.03s (29.01 ms/step | 34.47 steps/s | this 500 steps: 35.89 steps/s)
# Timing step 2500: 71.96s (28.79 ms/step | 34.74 steps/s | this 500 steps: 35.88 steps/s)
# Step 2999: scaling = -5.4587e-06, chi^2 = 2.0721e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.55 remaining
# Timing step 3000: 85.90s (28.63 ms/step | 34.92 steps/s | this 500 steps: 35.87 steps/s)
# Timing step 3500: 99.99s (28.57 ms/step | 35.00 steps/s | this 500 steps: 35.49 steps/s)
# Step 3999: scaling = -5.0116e-03, chi^2 = 1.8954e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.55 remaining
# Timing step 4000: 113.97s (28.49 ms/step | 35.10 steps/s | this 500 steps: 35.77 steps/s)
# Timing step 4500: 127.89s (28.42 ms/step | 35.19 steps/s | this 500 steps: 35.94 steps/s)
# Step 4999: scaling = -3.5848e-03, chi^2 = 1.7801e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.58 remaining
# Timing step 5000: 141.86s (28.37 ms/step | 35.25 steps/s | this 500 steps: 35.78 steps/s)
# Timing step 5500: 155.73s (28.32 ms/step | 35.32 steps/s | this 500 steps: 36.04 steps/s)
# Step 5999: scaling = 7.5512e-05, chi^2 = 1.6762e-044
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.60 remaining
# Timing step 6000: 169.69s (28.28 ms/step | 35.36 steps/s | this 500 steps: 35.83 steps/s)
# Timing step 6500: 183.63s (28.25 ms/step | 35.40 steps/s | this 500 steps: 35.86 steps/s)
# Step 6999: scaling = -5.5141e-04, chi^2 = 1.5742e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.57 remaining
# Timing step 7000: 197.64s (28.23 ms/step | 35.42 steps/s | this 500 steps: 35.68 steps/s)
# Timing step 7500: 211.76s (28.23 ms/step | 35.42 steps/s | this 500 steps: 35.43 steps/s)
# Step 7999: scaling = -1.1690e-03, chi^2 = 1.4993e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.62 remaining
# Timing step 8000: 225.79s (28.22 ms/step | 35.43 steps/s | this 500 steps: 35.63 steps/s)
# Timing step 8500: 239.78s (28.21 ms/step | 35.45 steps/s | this 500 steps: 35.75 steps/s)
# Step 8999: scaling = -1.3146e-04, chi^2 = 1.4513e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.61 remaining
# Timing step 9000: 253.71s (28.19 ms/step | 35.47 steps/s | this 500 steps: 35.88 steps/s)
# Timing step 9500: 267.71s (28.18 ms/step | 35.49 steps/s | this 500 steps: 35.73 steps/s)
# Step 9999: scaling = -6.3790e-05, chi^2 = 1.4300e-04
# Stray feature removal: Map has 1 blobs, removing 0 of them
# Zeroed 0.00 carbon-equivalents, 7.65 remaining
# Timing step 10000: 281.73s (28.17 ms/step | 35.50 steps/s | this 500 steps: 35.66 steps/s)
# Step 10000: scaling = -2.7638e-05, chi^2 = 1.4300e-04

# %%
weight_list = np.array(weight_list)

# %%
weight_list.mean(0).shape
# Out:
# (27000,)

# %%
for idx, w in enumerate(weight_list):
    write_out(xyz, w, f'data/6ND3/run{idx}.pdb')

# %%
write_out(xyz, weight_list.mean(0), 'data/6ND3/run_average.pdb', grid='data/6ND3/grid.pdb', op=allowed_points)

# %%
weighted_weight = (1/np.array(chi_list)[:, None] * weight_list).sum(0) / (1/np.array(chi_list)).sum()
write_out(xyz, weighted_weight, 'data/6ND3/run_average_weighted.pdb', grid='data/6ND3/grid.pdb', op=allowed_points)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(3, 1)
ax[0].plot(chi_trace)
ax[0].set_yscale('log')
ax[0].set_ylabel('chi2')
ax[1].plot(scale_trace,'.', markersize=2)
ax[1].set_ylabel('scaling')
ax[2].plot(np.array(fine_timing_trace)*1000,'.', markersize=2)
ax[2].set_ylabel('Timing (ms)')
# Out:
# Text(0, 0.5, 'Timing (ms)')

# %%
plt.plot(scatter.q, S_calc_all, label='target')
plt.yscale('log')
plt.plot(scatter.q, S_calc_pro_before, label='before')
plt.plot(scatter.q, final_S_calc, label='after')
# plt.plot(scatter.q, S_calc_trial, label='chain B')
# plt.plot(scatter.q, S_calc_cross, label='chain A x chain B')
# plt.plot(scatter.q, S_calc_pro + S_calc_trial + 2 * S_calc_cross, label='trial')
plt.legend()

# %%
# plt.plot(scatter.q, S_calc_all, label='target')
# plt.yscale('log')
plt.plot(scatter.q, S_calc_all -S_calc_pro_before, label='before')
plt.plot(scatter.q, S_calc_all - final_S_calc, label='after')
# plt.plot(scatter.q, S_calc_trial, label='chain B')
# plt.plot(scatter.q, S_calc_cross, label='chain A x chain B')
# plt.plot(scatter.q, S_calc_pro + S_calc_trial + 2 * S_calc_cross, label='separate')
plt.legend()

# %%
write_out(xyz, weight, 'test.pdb', grid='grid.pdb', op=op)

# %%
import matplotlib.pyplot as plt
plt.plot(scatter.q, (S_calc_all - S_calc_pro) / S_calc_all)
